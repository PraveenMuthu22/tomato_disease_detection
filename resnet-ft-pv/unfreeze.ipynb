# %% [markdown]
# # Arguments

# %%
warmup_model_path = 'model-warmedup.h5'
model_save_path = 'model-fine-tuned.h5'
dataset_name = 'tomato-dataset'
dataset_path = '../datasets/' + dataset_name
checkpoint_path = 'checkpoints-finetuning.hdf5'
input_width = 224
input_height = 224
input_depth = 3

batch_size = 32
num_of_epochs = 150

import sys
sys.path.append('..')

# Get classes
import os
import re
classes = os.listdir(dataset_path)
class_names = []

for i in classes:
    if(re.search("Tomato___", i)):
        class_names.append(i)
    
print('Classes: ', class_names)
print(len(class_names))
# Out:
# Classes:  ['Tomato___Tomato_mosaic_virus', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Bacterial_spot', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___healthy', 'Tomato___Septoria_leaf_spot', 'Tomato___Two-spotted_spider_mite']
# 10

# %% [markdown]
# # Load model from disk

# %%
# import tensorflow as tf
# print(tf.__version__)


# model = tf.keras.models.load_model(
#     warmup_model_path,
#     custom_objects=None,
#     compile=False
# )

from keras.models import load_model

model = load_model(warmup_model_path)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Print index of layers

# %%
# iterate for all layers in the network and print its' index value
for (i,layer) in enumerate(model.layers):
    print("[INFO] {}\t{}".format(i,layer.__class__.__name__))
# Out:
# [INFO] 0	InputLayer
# [INFO] 1	ZeroPadding2D
# [INFO] 2	Conv2D
# [INFO] 3	BatchNormalization
# [INFO] 4	Activation
# [INFO] 5	ZeroPadding2D
# [INFO] 6	MaxPooling2D
# [INFO] 7	Conv2D
# [INFO] 8	BatchNormalization
# [INFO] 9	Activation
# [INFO] 10	Conv2D
# [INFO] 11	BatchNormalization
# [INFO] 12	Activation
# [INFO] 13	Conv2D
# [INFO] 14	Conv2D
# [INFO] 15	BatchNormalization
# [INFO] 16	BatchNormalization
# [INFO] 17	Add
# [INFO] 18	Activation
# [INFO] 19	Conv2D
# [INFO] 20	BatchNormalization
# [INFO] 21	Activation
# [INFO] 22	Conv2D
# [INFO] 23	BatchNormalization
# [INFO] 24	Activation
# [INFO] 25	Conv2D
# [INFO] 26	BatchNormalization
# [INFO] 27	Add
# [INFO] 28	Activation
# [INFO] 29	Conv2D
# [INFO] 30	BatchNormalization
# [INFO] 31	Activation
# [INFO] 32	Conv2D
# [INFO] 33	BatchNormalization
# [INFO] 34	Activation
# [INFO] 35	Conv2D
# [INFO] 36	BatchNormalization
# [INFO] 37	Add
# [INFO] 38	Activation
# [INFO] 39	Conv2D
# [INFO] 40	BatchNormalization
# [INFO] 41	Activation
# [INFO] 42	Conv2D
# [INFO] 43	BatchNormalization
# [INFO] 44	Activation
# [INFO] 45	Conv2D
# [INFO] 46	Conv2D
# [INFO] 47	BatchNormalization
# [INFO] 48	BatchNormalization
# [INFO] 49	Add
# [INFO] 50	Activation
# [INFO] 51	Conv2D
# [INFO] 52	BatchNormalization
# [INFO] 53	Activation
# [INFO] 54	Conv2D
# [INFO] 55	BatchNormalization
# [INFO] 56	Activation
# [INFO] 57	Conv2D
# [INFO] 58	BatchNormalization
# [INFO] 59	Add
# [INFO] 60	Activation
# [INFO] 61	Conv2D
# [INFO] 62	BatchNormalization
# [INFO] 63	Activation
# [INFO] 64	Conv2D
# [INFO] 65	BatchNormalization
# [INFO] 66	Activation
# [INFO] 67	Conv2D
# [INFO] 68	BatchNormalization
# [INFO] 69	Add
# [INFO] 70	Activation
# [INFO] 71	Conv2D
# [INFO] 72	BatchNormalization
# [INFO] 73	Activation
# [INFO] 74	Conv2D
# [INFO] 75	BatchNormalization
# [INFO] 76	Activation
# [INFO] 77	Conv2D
# [INFO] 78	BatchNormalization
# [INFO] 79	Add
# [INFO] 80	Activation
# [INFO] 81	Conv2D
# [INFO] 82	BatchNormalization
# [INFO] 83	Activation
# [INFO] 84	Conv2D
# [INFO] 85	BatchNormalization
# [INFO] 86	Activation
# [INFO] 87	Conv2D
# [INFO] 88	Conv2D
# [INFO] 89	BatchNormalization
# [INFO] 90	BatchNormalization
# [INFO] 91	Add
# [INFO] 92	Activation
# [INFO] 93	Conv2D
# [INFO] 94	BatchNormalization
# [INFO] 95	Activation
# [INFO] 96	Conv2D
# [INFO] 97	BatchNormalization
# [INFO] 98	Activation
# [INFO] 99	Conv2D
# [INFO] 100	BatchNormalization
# [INFO] 101	Add
# [INFO] 102	Activation
# [INFO] 103	Conv2D
# [INFO] 104	BatchNormalization
# [INFO] 105	Activation
# [INFO] 106	Conv2D
# [INFO] 107	BatchNormalization
# [INFO] 108	Activation
# [INFO] 109	Conv2D
# [INFO] 110	BatchNormalization
# [INFO] 111	Add
# [INFO] 112	Activation
# [INFO] 113	Conv2D
# [INFO] 114	BatchNormalization
# [INFO] 115	Activation
# [INFO] 116	Conv2D
# [INFO] 117	BatchNormalization
# [INFO] 118	Activation
# [INFO] 119	Conv2D
# [INFO] 120	BatchNormalization
# [INFO] 121	Add
# [INFO] 122	Activation
# [INFO] 123	Conv2D
# [INFO] 124	BatchNormalization
# [INFO] 125	Activation
# [INFO] 126	Conv2D
# [INFO] 127	BatchNormalization
# [INFO] 128	Activation
# [INFO] 129	Conv2D
# [INFO] 130	BatchNormalization
# [INFO] 131	Add
# [INFO] 132	Activation
# [INFO] 133	Conv2D
# [INFO] 134	BatchNormalization
# [INFO] 135	Activation
# [INFO] 136	Conv2D
# [INFO] 137	BatchNormalization
# [INFO] 138	Activation
# [INFO] 139	Conv2D
# [INFO] 140	BatchNormalization
# [INFO] 141	Add
# [INFO] 142	Activation
# [INFO] 143	Conv2D
# [INFO] 144	BatchNormalization
# [INFO] 145	Activation
# [INFO] 146	Conv2D
# [INFO] 147	BatchNormalization
# [INFO] 148	Activation
# [INFO] 149	Conv2D
# [INFO] 150	Conv2D
# [INFO] 151	BatchNormalization
# [INFO] 152	BatchNormalization
# [INFO] 153	Add
# [INFO] 154	Activation
# [INFO] 155	Conv2D
# [INFO] 156	BatchNormalization
# [INFO] 157	Activation
# [INFO] 158	Conv2D
# [INFO] 159	BatchNormalization
# [INFO] 160	Activation
# [INFO] 161	Conv2D
# [INFO] 162	BatchNormalization
# [INFO] 163	Add
# [INFO] 164	Activation
# [INFO] 165	Conv2D
# [INFO] 166	BatchNormalization
# [INFO] 167	Activation
# [INFO] 168	Conv2D
# [INFO] 169	BatchNormalization
# [INFO] 170	Activation
# [INFO] 171	Conv2D
# [INFO] 172	BatchNormalization
# [INFO] 173	Add
# [INFO] 174	Activation
# [INFO] 175	Flatten
# [INFO] 176	Dense
# [INFO] 177	Dropout
# [INFO] 178	Dense

# %% [markdown]
# # Unfreeze final layers

# %%
# for layer in model.layers[168:]:
#     layer.trainable = True

# for layer in model.layers[165:]:
#     layer.trainable = True
    
for layer in model.layers[161:]:
    layer.trainable = True

# %% [markdown]
# # Compile model

# %%
from keras.optimizers import SGD

# Build the model from the new
print("[INFO] re-compiling model ...")
opt = SGD(lr=0.001)
# Fine-tuning with a small learning rate
model.compile(loss = 'categorical_crossentropy',optimizer = opt,
              metrics=['accuracy'])
# Out:
# [INFO] re-compiling model ...

# %% [markdown]
# # Load data

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.preprocessing.image   import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.layers import Input
from keras.models import Model
from keras .applications import VGG16
from keras.optimizers import SGD
from keras.models import Model
from imutils import paths
import numpy as np
import os

import sys
sys.path.append('..')

from utils.preprocessors.aspect_aware_preprocessor import AspectAwarePreprocessor
from utils.preprocessors.image_to_array_preprocessor import ImageToArrayPreprocessor
from utils.io.simple_dataset_loader import SimpleDatasetLoader

# construct the image generator for data augmentation
aug = ImageDataGenerator(   rotation_range=30,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            shear_range=0.2,
                            zoom_range=0.2,
                            horizontal_flip=True,
                            fill_mode='nearest')

# Load image paths
print("[INFO] loading images...")
image_paths = list(paths.list_images(dataset_path))

# Initial image preprocessing
aap = AspectAwarePreprocessor(input_width, input_height)
iap= ImageToArrayPreprocessor()

#Load image data and perform image data preprocessing
sdl = SimpleDatasetLoader(preprocessors=[aap,iap])
(data,labels)  = sdl.load(image_paths,verbose=500)
data = data.astype("float") / 255.0


# train test split
(train_x,test_x,train_y,test_y) = train_test_split(data,labels,test_size=0.25,random_state=42)

# convert the labels from integers to vectors
train_y = LabelBinarizer().fit_transform(train_y)
test_y = LabelBinarizer().fit_transform(test_y)
# Out:
# [INFO] loading images...
# [INFO]: Processed 500/18160
# [INFO]: Processed 1000/18160
# [INFO]: Processed 1500/18160
# [INFO]: Processed 2000/18160
# [INFO]: Processed 2500/18160
# [INFO]: Processed 3000/18160
# [INFO]: Processed 3500/18160
# [INFO]: Processed 4000/18160
# [INFO]: Processed 4500/18160
# [INFO]: Processed 5000/18160
# [INFO]: Processed 5500/18160
# [INFO]: Processed 6000/18160
# [INFO]: Processed 6500/18160
# [INFO]: Processed 7000/18160
# [INFO]: Processed 7500/18160
# [INFO]: Processed 8000/18160
# [INFO]: Processed 8500/18160
# [INFO]: Processed 9000/18160
# [INFO]: Processed 9500/18160
# [INFO]: Processed 10000/18160
# [INFO]: Processed 10500/18160
# [INFO]: Processed 11000/18160
# [INFO]: Processed 11500/18160
# [INFO]: Processed 12000/18160
# [INFO]: Processed 12500/18160
# [INFO]: Processed 13000/18160
# [INFO]: Processed 13500/18160
# [INFO]: Processed 14000/18160
# [INFO]: Processed 14500/18160
# [INFO]: Processed 15000/18160
# [INFO]: Processed 15500/18160
# [INFO]: Processed 16000/18160
# [INFO]: Processed 16500/18160
# [INFO]: Processed 17000/18160
# [INFO]: Processed 17500/18160
# [INFO]: Processed 18000/18160

# %% [markdown]
# # Checkpoints

# %%
from keras.callbacks import ModelCheckpoint


checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', mode='max', 
save_best_only=True, verbose=1)

callbacks = [checkpoint]

import os

# First layers unfrozen
epochs_done = 91

if(os.path.exists(checkpoint_path)):
    model.load_weights(checkpoint_path)
    num_of_epochs = num_of_epochs - epochs_done

# %% [markdown]
# # Training monitor

# %%
# from utils.callbacks.training_monitor import TrainingMonitor
# import pathlib

# callbacks = []

# # Give absolute path
# currentPath = str(pathlib.Path().absolute())
# print(currentPath)

# # Construct the set of callbacks
# fig_path = os.path.sep.join([currentPath,  "{}.png".format(os.getpid())])
# json_path = os.path.sep.join([currentPath, "{}.json".format(os.getpid())])
# print(fig_path)
# print(json_path)
# callbacks.append(TrainingMonitor(fig_path, json_path=json_path))

# print(num_of_epochs)

# %% [markdown]
# # Fit model

# %%
H = model.fit_generator(
        aug.flow(train_x,train_y, batch_size = 32),
                validation_data = (test_x,test_y),
                epochs=num_of_epochs,
                steps_per_epoch = len(train_x) //32,
                verbose = 1,
                callbacks=callbacks)

model.save(model_save_path)
# Out:
# Epoch 1/59
# 425/425 [==============================] - 227s 533ms/step - loss: 0.2722 - accuracy: 0.9208 - val_loss: 87.9424 - val_accuracy: 0.1119
#
# Epoch 00001: val_accuracy improved from -inf to 0.11189, saving model to checkpoints-finetuning.hdf5
# Epoch 2/59
# 425/425 [==============================] - 221s 520ms/step - loss: 0.2595 - accuracy: 0.9219 - val_loss: 91.5761 - val_accuracy: 0.2482
#
# Epoch 00002: val_accuracy improved from 0.11189 to 0.24824, saving model to checkpoints-finetuning.hdf5
# Epoch 3/59
# 425/425 [==============================] - 215s 506ms/step - loss: 0.2501 - accuracy: 0.9257 - val_loss: 91.2891 - val_accuracy: 0.1183
#
# Epoch 00003: val_accuracy did not improve from 0.24824
# Epoch 4/59
# 425/425 [==============================] - 215s 506ms/step - loss: 0.2509 - accuracy: 0.9235 - val_loss: 92.9060 - val_accuracy: 0.2985
#
# Epoch 00004: val_accuracy improved from 0.24824 to 0.29846, saving model to checkpoints-finetuning.hdf5
# Epoch 5/59
# 425/425 [==============================] - 216s 508ms/step - loss: 0.2443 - accuracy: 0.9288 - val_loss: 88.4751 - val_accuracy: 0.3051
#
# Epoch 00005: val_accuracy improved from 0.29846 to 0.30507, saving model to checkpoints-finetuning.hdf5
# Epoch 6/59
# 425/425 [==============================] - 221s 520ms/step - loss: 0.2534 - accuracy: 0.9220 - val_loss: 90.0611 - val_accuracy: 0.3022
#
# Epoch 00006: val_accuracy did not improve from 0.30507
# Epoch 7/59
# 425/425 [==============================] - 222s 522ms/step - loss: 0.2520 - accuracy: 0.9266 - val_loss: 90.4322 - val_accuracy: 0.2987
#
# Epoch 00007: val_accuracy did not improve from 0.30507
# Epoch 8/59
# 425/425 [==============================] - 220s 517ms/step - loss: 0.2652 - accuracy: 0.9218 - val_loss: 94.7654 - val_accuracy: 0.2278
#
# Epoch 00008: val_accuracy did not improve from 0.30507
# Epoch 9/59
# 425/425 [==============================] - 217s 509ms/step - loss: 0.2644 - accuracy: 0.9207 - val_loss: 93.2124 - val_accuracy: 0.1035
#
# Epoch 00009: val_accuracy did not improve from 0.30507
# Epoch 10/59
# 425/425 [==============================] - 215s 505ms/step - loss: 0.2520 - accuracy: 0.9238 - val_loss: 91.9340 - val_accuracy: 0.1601
#
# Epoch 00010: val_accuracy did not improve from 0.30507
# Epoch 11/59
# 425/425 [==============================] - 215s 507ms/step - loss: 0.2430 - accuracy: 0.9297 - val_loss: 90.4749 - val_accuracy: 0.3051
#
# Epoch 00011: val_accuracy did not improve from 0.30507
# Epoch 12/59
# 425/425 [==============================] - 214s 504ms/step - loss: 0.2493 - accuracy: 0.9265 - val_loss: 90.1888 - val_accuracy: 0.2989
#
# Epoch 00012: val_accuracy did not improve from 0.30507
# Epoch 13/59
# 425/425 [==============================] - 216s 507ms/step - loss: 0.2510 - accuracy: 0.9252 - val_loss: 90.6579 - val_accuracy: 0.1374
#
# Epoch 00013: val_accuracy did not improve from 0.30507
# Epoch 14/59
# 425/425 [==============================] - 214s 504ms/step - loss: 0.2590 - accuracy: 0.9244 - val_loss: 94.1228 - val_accuracy: 0.2985
#
# Epoch 00014: val_accuracy did not improve from 0.30507
# Epoch 15/59
# 425/425 [==============================] - 214s 504ms/step - loss: 0.2334 - accuracy: 0.9320 - val_loss: 90.7810 - val_accuracy: 0.2659
#
# Epoch 00015: val_accuracy did not improve from 0.30507
# Epoch 16/59
# 425/425 [==============================] - 215s 505ms/step - loss: 0.2271 - accuracy: 0.9316 - val_loss: 92.0281 - val_accuracy: 0.2987
#
# Epoch 00016: val_accuracy did not improve from 0.30507
# Epoch 17/59
# 425/425 [==============================] - 215s 505ms/step - loss: 0.2370 - accuracy: 0.9296 - val_loss: 91.4429 - val_accuracy: 0.1330
#
# Epoch 00017: val_accuracy did not improve from 0.30507
# Epoch 18/59
# 425/425 [==============================] - 215s 506ms/step - loss: 0.2264 - accuracy: 0.9322 - val_loss: 88.9340 - val_accuracy: 0.1035
#
# Epoch 00018: val_accuracy did not improve from 0.30507
# Epoch 19/59
# 425/425 [==============================] - 215s 505ms/step - loss: 0.2356 - accuracy: 0.9306 - val_loss: 90.2668 - val_accuracy: 0.1185
#
# Epoch 00019: val_accuracy did not improve from 0.30507
# Epoch 20/59
# 425/425 [==============================] - 214s 503ms/step - loss: 0.2334 - accuracy: 0.9303 - val_loss: 92.8025 - val_accuracy: 0.2985
#
# Epoch 00020: val_accuracy did not improve from 0.30507
# Epoch 21/59
# 425/425 [==============================] - 212s 500ms/step - loss: 0.2425 - accuracy: 0.9303 - val_loss: 90.6033 - val_accuracy: 0.3024
#
# Epoch 00021: val_accuracy did not improve from 0.30507
# Epoch 22/59
# 425/425 [==============================] - 213s 501ms/step - loss: 0.2409 - accuracy: 0.9297 - val_loss: 90.8865 - val_accuracy: 0.3026
#
# Epoch 00022: val_accuracy did not improve from 0.30507
# Epoch 23/59
# 425/425 [==============================] - 213s 500ms/step - loss: 0.2326 - accuracy: 0.9305 - val_loss: 88.3980 - val_accuracy: 0.1033
#
# Epoch 00023: val_accuracy did not improve from 0.30507
# Epoch 24/59
# 425/425 [==============================] - 212s 499ms/step - loss: 0.2190 - accuracy: 0.9340 - val_loss: 90.1360 - val_accuracy: 0.1033
#
# Epoch 00024: val_accuracy did not improve from 0.30507
# Epoch 25/59
# 425/425 [==============================] - 211s 498ms/step - loss: 0.2339 - accuracy: 0.9316 - val_loss: 88.5642 - val_accuracy: 0.1033
#
# Epoch 00025: val_accuracy did not improve from 0.30507
# Epoch 26/59
# 425/425 [==============================] - 211s 497ms/step - loss: 0.2323 - accuracy: 0.9319 - val_loss: 89.4402 - val_accuracy: 0.1430
#
# Epoch 00026: val_accuracy did not improve from 0.30507
# Epoch 27/59
# 425/425 [==============================] - 211s 497ms/step - loss: 0.2292 - accuracy: 0.9337 - val_loss: 93.7171 - val_accuracy: 0.1035
#
# Epoch 00027: val_accuracy did not improve from 0.30507
# Epoch 28/59
# 425/425 [==============================] - 212s 498ms/step - loss: 0.2127 - accuracy: 0.9356 - val_loss: 89.5982 - val_accuracy: 0.1035
#
# Epoch 00028: val_accuracy did not improve from 0.30507
# Epoch 29/59
# 425/425 [==============================] - 211s 497ms/step - loss: 0.2186 - accuracy: 0.9333 - val_loss: 91.1995 - val_accuracy: 0.1035
#
# Epoch 00029: val_accuracy did not improve from 0.30507
# Epoch 30/59
# 425/425 [==============================] - 213s 501ms/step - loss: 0.2228 - accuracy: 0.9354 - val_loss: 87.5150 - val_accuracy: 0.1035
#
# Epoch 00030: val_accuracy did not improve from 0.30507
# Epoch 31/59
# 425/425 [==============================] - 213s 501ms/step - loss: 0.2142 - accuracy: 0.9361 - val_loss: 89.5034 - val_accuracy: 0.1035
#
# Epoch 00031: val_accuracy did not improve from 0.30507
# Epoch 32/59
# 229/425 [===============>..............] - ETA: 1:13 - loss: 0.2444 - accuracy: 0.9271
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-8d9d06787f3e> in <module>
#       5                 steps_per_epoch = len(train_x) //32,
#       6                 verbose = 1,
# ----> 7                 callbacks=callbacks)
#       8
#       9 model.save(model_save_path)
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3733     return nest.pack_sequence_as(
#    3734         self._outputs_structure,
# -> 3735         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3736         expand_composites=True)
#    3737
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/keras/backend.py in <listcomp>(.0)
#    3733     return nest.pack_sequence_as(
#    3734         self._outputs_structure,
# -> 3735         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3736         expand_composites=True)
#    3737
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/framework/ops.py in _numpy(self)
#     906     # pylint: disable=protected-access
#     907     try:
# --> 908       return self._numpy_internal()
#     909     except core._NotOkStatusException as e:
#     910       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %% [markdown]
# # Visualize

# %%
plot_save_path = 'plot-fine-tuned.png'

# plot the training loss and accuracy
from matplotlib import pyplot as plt

plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, num_of_epochs), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, num_of_epochs), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, num_of_epochs), H.history["accuracy"], label="train_accuracy")
plt.plot(np.arange(0, num_of_epochs), H.history["val_accuracy"], label="val_accuracy")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
#save to disk
plt.savefig(plot_save_path)
plt.show()

# %% [markdown]
# # Evaluate

# %%
from sklearn.metrics import classification_report

print("[INFO] evaluating after initialization...")
predictions = model.predict(test_x,batch_size=batch_size)
print(classification_report(test_y.argmax(axis =1),
                            predictions.argmax(axis =1),target_names=class_names))
