# %% [markdown]
# # Arguments

# %%
#vgg16-fs-pv
num_of_epochs = 25
batch_size = 32
dataset_path_plantvillage = '../datasets/plantvillage'
dataset_path_self = '../datasets/self'
dataset_path_validation = '../datasets/validation'

dataset_paths = [dataset_path_plantvillage, dataset_path_self, dataset_path_validation]

model_save_path = 'model-warmup.h5'

checkpoint_path = 'checkpoints-warmup.hdf5'

input_width = 224
input_height = 224
input_depth = 3

# %% [markdown]
# # Print class names

# %%
# Get classes
import os
import re

class_names = []
class_paths_plant_village = []
class_paths_plant_self = []
class_paths_plant_validation = []

for path in dataset_paths:
    classes = os.listdir(path)
    for i in classes:
        if(re.search('___', i)):
            if(i not in class_names):
                class_names.append(i)
            if(re.search('plantvillage', path)):
                class_paths_plant_village.append(path + '/' + i)
            elif(re.search('self', path)):
                class_paths_plant_self.append(path + '/' + i)
            else:
                class_paths_plant_validation.append(path + '/' + i)

print(class_names)   
print()
print('PlantVillage')
print(class_paths_plant_village) 
print(len(class_paths_plant_village))
print()
print('Self')
print(class_paths_plant_self) 
print(len(class_paths_plant_self))
print()
print('Validation')
print(class_paths_plant_validation) 
print(len(class_paths_plant_validation))
# Out:
# ['___Yellow_Leaf_Curl_Virus', '___Late_blight', '___Early_blight', '___Two-spotted_spider_mite', '___Septoria_leaf_spot', '___Bacterial_spot', '___healthy', '___Target_Spot', '___Mosaic_Virus', '___Leaf_Mold', '___Leaf_miner', '___Appids']
#
# PlantVillage
# ['../datasets/plantvillage/___Yellow_Leaf_Curl_Virus', '../datasets/plantvillage/___Late_blight', '../datasets/plantvillage/___Early_blight', '../datasets/plantvillage/___Two-spotted_spider_mite', '../datasets/plantvillage/___Septoria_leaf_spot', '../datasets/plantvillage/___Bacterial_spot', '../datasets/plantvillage/___healthy', '../datasets/plantvillage/___Target_Spot', '../datasets/plantvillage/___Mosaic_Virus', '../datasets/plantvillage/___Leaf_Mold']
# 10
#
# Self
# ['../datasets/self/___Leaf_miner', '../datasets/self/___Early_blight', '../datasets/self/___Appids']
# 3
#
# Validation
# ['../datasets/validation/___Leaf_miner', '../datasets/validation/___Yellow_Leaf_Curl_Virus', '../datasets/validation/___Late_blight', '../datasets/validation/___Early_blight', '../datasets/validation/___Bacterial_spot', '../datasets/validation/___healthy', '../datasets/validation/___Appids', '../datasets/validation/___Target_Spot', '../datasets/validation/___Mosaic_Virus', '../datasets/validation/___Leaf_Mold']
# 10

# %% [markdown]
# # Select training classes
#
# early blight in plantVillage dataset replaced by self one

# %%
class_paths_training = ['../datasets/plantvillage/___Late_blight', '../datasets/plantvillage/___Target_Spot', '../datasets/plantvillage/___healthy', '../datasets/plantvillage/___Mosaic_Virus', '../datasets/plantvillage/___Yellow_Leaf_Curl_Virus', '../datasets/plantvillage/___Leaf_Mold', '../datasets/plantvillage/___Bacterial_spot', '../datasets/plantvillage/___Early_blight']

# %% [markdown]
# # Load dataset

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.preprocessing.image   import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.layers import Input
from keras.models import Model
from keras .applications import VGG16
from keras.optimizers import SGD
from keras.models import Model
from imutils import paths
import numpy as np
import os

import sys
sys.path.append('..')

from utils.preprocessors.aspect_aware_preprocessor import AspectAwarePreprocessor
from utils.preprocessors.image_to_array_preprocessor import ImageToArrayPreprocessor
from utils.io.simple_dataset_loader import SimpleDatasetLoader

# construct the image generator for data augmentation
aug = ImageDataGenerator(   rotation_range=30,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            shear_range=0.2,
                            zoom_range=0.2,
                            horizontal_flip=True,
                            fill_mode='nearest')

# Load image paths
image_paths = []
print("[INFO] loading images...")
for path in class_paths_training:
    image_paths.extend(list(paths.list_images(path)))
    
# Get unique classnames

class_names = [pt.split(os.path.sep)[-2] for pt in image_paths]
class_names = [str(x) for x in np.unique(class_names)]

# Initial image preprocessing
aap = AspectAwarePreprocessor(input_width, input_height)
iap= ImageToArrayPreprocessor()

#Load image data and perform image data preprocessing
sdl = SimpleDatasetLoader(preprocessors=[aap,iap])
(data,labels)  = sdl.load(image_paths,verbose=500)
data = data.astype("float") / 255.0


# train test split
(train_x,test_x,train_y,test_y) = train_test_split(data,labels,test_size=0.25,random_state=42)

# convert the labels from integers to vectors
train_y = LabelBinarizer().fit_transform(train_y)
test_y = LabelBinarizer().fit_transform(test_y)
# Out:
# Using TensorFlow backend.
# [INFO] loading images...
# [INFO]: Processed 500/14713
# [INFO]: Processed 1000/14713
# [INFO]: Processed 1500/14713
# [INFO]: Processed 2000/14713
# [INFO]: Processed 2500/14713
# [INFO]: Processed 3000/14713
# [INFO]: Processed 3500/14713
# [INFO]: Processed 4000/14713
# [INFO]: Processed 4500/14713
# [INFO]: Processed 5000/14713
# [INFO]: Processed 5500/14713
# [INFO]: Processed 6000/14713
# [INFO]: Processed 6500/14713
# [INFO]: Processed 7000/14713
# [INFO]: Processed 7500/14713
# [INFO]: Processed 8000/14713
# [INFO]: Processed 8500/14713
# [INFO]: Processed 9000/14713
# [INFO]: Processed 9500/14713
# [INFO]: Processed 10000/14713
# [INFO]: Processed 10500/14713
# [INFO]: Processed 11000/14713
# [INFO]: Processed 11500/14713
# [INFO]: Processed 12000/14713
# [INFO]: Processed 12500/14713
# [INFO]: Processed 13000/14713
# [INFO]: Processed 13500/14713
# [INFO]: Processed 14000/14713
# [INFO]: Processed 14500/14713

# %% [markdown]
# # Load model

# %%
from keras.applications import VGG16
from keras.utils.vis_utils import plot_model
from keras.layers import Input



# Load pretrianed VGG model with FC layers removed
# explicitly deﬁne the input_tensor to be 224×224×3 pixels
base_model = VGG16( weights=None,
                    include_top=False,
                    input_tensor=Input(shape = (input_width,input_height, input_depth)))

plot_save_path = 'diagram-top-removed.png'
# plot_model(base_model, to_file=plot_save_path, show_shapes=True)

# %% [markdown]
# # Custom FC layer

# %%
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense

head_model = base_model.output
head_model = Flatten(name='flatten')(head_model)
head_model = Dense(4096,activation='relu')(head_model)
head_model = Dense(4096,activation='relu')(head_model)
# Add a softmaxc layer
head_model = Dense(len(class_names),activation='softmax')(head_model)

# %% [markdown]
# # Attach custom head to model

# %%
from keras.models import Model


# place the head FC model on top of the base model 
model = Model(inputs=base_model.input, outputs = head_model)

# plot_save_path = 'diagram-head-attached.png'
# plot_model(model, to_file=plot_save_path, show_shapes=True)

# %% [markdown]
# # Compile model

# %%
from keras.optimizers import SGD

# Build the model from the new
print("[INFO] re-compiling model ...")
opt = SGD(lr=0.001, momentum=0.09)

model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])
# Since we only train the new fully connected layer, we do a few iterations
# Out:
# [INFO] re-compiling model ...

# %% [markdown]
# # Checkpoints

# %%
from keras.callbacks import ModelCheckpoint


checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', mode='min', 
save_best_only=True, verbose=1)

callbacks = [checkpoint]

# %%
#load checkpoints if existing

import os

if(os.path.exists(checkpoint_path)):
    model.load_weights(checkpoint_path)

# %% [markdown]
# # Training monitor

# %%
from utils.callbacks.training_monitor import TrainingMonitor
import pathlib
import json
import os

fig_path = "plot"
json_path = "values.json"
values_path = 'values.json'

start_epoch = 0

callbacks.append(TrainingMonitor(fig_path, json_path, start_epoch))

# %% [markdown]
# # Warm up head

# %%
num_of_epochs = 67

model.fit_generator(
    aug.flow(train_x,train_y, batch_size = 32),
             validation_data = (test_x,test_y),
             epochs=num_of_epochs,
             steps_per_epoch = len(train_x) //32,
             verbose = 1,
             callbacks=callbacks)

model.save(model_save_path)
# Out:
# Epoch 1/67
# 344/344 [==============================] - 369s 1s/step - loss: 0.2515 - accuracy: 0.9107 - val_loss: 0.1916 - val_accuracy: 0.9304
#
# Epoch 00001: val_loss improved from inf to 0.19163, saving model to checkpoints-warmup.hdf5
# Epoch 2/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.2467 - accuracy: 0.9132 - val_loss: 0.1700 - val_accuracy: 0.9416
#
# Epoch 00002: val_loss improved from 0.19163 to 0.16996, saving model to checkpoints-warmup.hdf5
# Epoch 3/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.2426 - accuracy: 0.9130 - val_loss: 0.2227 - val_accuracy: 0.9176
#
# Epoch 00003: val_loss did not improve from 0.16996
# Epoch 4/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.2354 - accuracy: 0.9155 - val_loss: 0.1619 - val_accuracy: 0.9388
#
# Epoch 00004: val_loss improved from 0.16996 to 0.16195, saving model to checkpoints-warmup.hdf5
# Epoch 5/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.2210 - accuracy: 0.9209 - val_loss: 0.1601 - val_accuracy: 0.9426
#
# Epoch 00005: val_loss improved from 0.16195 to 0.16006, saving model to checkpoints-warmup.hdf5
# Epoch 6/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.2510 - accuracy: 0.9151 - val_loss: 0.1629 - val_accuracy: 0.9446
#
# Epoch 00006: val_loss did not improve from 0.16006
# Epoch 7/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.2115 - accuracy: 0.9242 - val_loss: 0.1323 - val_accuracy: 0.9554
#
# Epoch 00007: val_loss improved from 0.16006 to 0.13228, saving model to checkpoints-warmup.hdf5
# Epoch 8/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.2170 - accuracy: 0.9217 - val_loss: 0.1414 - val_accuracy: 0.9541
#
# Epoch 00008: val_loss did not improve from 0.13228
# Epoch 9/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.2006 - accuracy: 0.9292 - val_loss: 0.1764 - val_accuracy: 0.9426
#
# Epoch 00009: val_loss did not improve from 0.13228
# Epoch 10/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.1970 - accuracy: 0.9317 - val_loss: 0.1370 - val_accuracy: 0.9519
#
# Epoch 00010: val_loss did not improve from 0.13228
# Epoch 11/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.2084 - accuracy: 0.9271 - val_loss: 0.1902 - val_accuracy: 0.9356
#
# Epoch 00011: val_loss did not improve from 0.13228
# Epoch 12/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1912 - accuracy: 0.9315 - val_loss: 0.1328 - val_accuracy: 0.9513
#
# Epoch 00012: val_loss did not improve from 0.13228
# Epoch 13/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1849 - accuracy: 0.9343 - val_loss: 0.1260 - val_accuracy: 0.9581
#
# Epoch 00013: val_loss improved from 0.13228 to 0.12601, saving model to checkpoints-warmup.hdf5
# Epoch 14/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1895 - accuracy: 0.9349 - val_loss: 0.1189 - val_accuracy: 0.9584
#
# Epoch 00014: val_loss improved from 0.12601 to 0.11885, saving model to checkpoints-warmup.hdf5
# Epoch 15/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.1777 - accuracy: 0.9352 - val_loss: 0.3702 - val_accuracy: 0.8742
#
# Epoch 00015: val_loss did not improve from 0.11885
# Epoch 16/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1753 - accuracy: 0.9390 - val_loss: 0.2894 - val_accuracy: 0.9084
#
# Epoch 00016: val_loss did not improve from 0.11885
# Epoch 17/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1694 - accuracy: 0.9397 - val_loss: 0.1527 - val_accuracy: 0.9492
#
# Epoch 00017: val_loss did not improve from 0.11885
# Epoch 18/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.1811 - accuracy: 0.9368 - val_loss: 0.1206 - val_accuracy: 0.9576
#
# Epoch 00018: val_loss did not improve from 0.11885
# Epoch 19/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1580 - accuracy: 0.9415 - val_loss: 0.1459 - val_accuracy: 0.9516
#
# Epoch 00019: val_loss did not improve from 0.11885
# Epoch 20/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1537 - accuracy: 0.9471 - val_loss: 0.1264 - val_accuracy: 0.9600
#
# Epoch 00020: val_loss did not improve from 0.11885
# Epoch 21/67
# 344/344 [==============================] - 346s 1s/step - loss: 0.1712 - accuracy: 0.9400 - val_loss: 0.1516 - val_accuracy: 0.9451
#
# Epoch 00021: val_loss did not improve from 0.11885
# Epoch 22/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1470 - accuracy: 0.9474 - val_loss: 0.1295 - val_accuracy: 0.9560
#
# Epoch 00022: val_loss did not improve from 0.11885
# Epoch 23/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1464 - accuracy: 0.9456 - val_loss: 0.1045 - val_accuracy: 0.9641
#
# Epoch 00023: val_loss improved from 0.11885 to 0.10453, saving model to checkpoints-warmup.hdf5
# Epoch 24/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1480 - accuracy: 0.9473 - val_loss: 0.1346 - val_accuracy: 0.9568
#
# Epoch 00024: val_loss did not improve from 0.10453
# Epoch 25/67
# 344/344 [==============================] - 346s 1s/step - loss: 0.1347 - accuracy: 0.9555 - val_loss: 0.1223 - val_accuracy: 0.9579
#
# Epoch 00025: val_loss did not improve from 0.10453
# Epoch 26/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1504 - accuracy: 0.9461 - val_loss: 0.1225 - val_accuracy: 0.9584
#
# Epoch 00026: val_loss did not improve from 0.10453
# Epoch 27/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1451 - accuracy: 0.9483 - val_loss: 0.1210 - val_accuracy: 0.9595
#
# Epoch 00027: val_loss did not improve from 0.10453
# Epoch 28/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1374 - accuracy: 0.9532 - val_loss: 0.1363 - val_accuracy: 0.9508
#
# Epoch 00028: val_loss did not improve from 0.10453
# Epoch 29/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1401 - accuracy: 0.9504 - val_loss: 0.1195 - val_accuracy: 0.9614
#
# Epoch 00029: val_loss did not improve from 0.10453
# Epoch 30/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1241 - accuracy: 0.9559 - val_loss: 0.1282 - val_accuracy: 0.9590
#
# Epoch 00030: val_loss did not improve from 0.10453
# Epoch 31/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1294 - accuracy: 0.9545 - val_loss: 0.1350 - val_accuracy: 0.9571
#
# Epoch 00031: val_loss did not improve from 0.10453
# Epoch 32/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1343 - accuracy: 0.9506 - val_loss: 0.0936 - val_accuracy: 0.9701
#
# Epoch 00032: val_loss improved from 0.10453 to 0.09359, saving model to checkpoints-warmup.hdf5
# Epoch 33/67
# 344/344 [==============================] - 346s 1s/step - loss: 0.1242 - accuracy: 0.9575 - val_loss: 0.1060 - val_accuracy: 0.9666
#
# Epoch 00033: val_loss did not improve from 0.09359
# Epoch 34/67
# 344/344 [==============================] - 346s 1s/step - loss: 0.1235 - accuracy: 0.9564 - val_loss: 0.1089 - val_accuracy: 0.9625
#
# Epoch 00034: val_loss did not improve from 0.09359
# Epoch 35/67
# 344/344 [==============================] - 346s 1s/step - loss: 0.1171 - accuracy: 0.9610 - val_loss: 0.1078 - val_accuracy: 0.9625
#
# Epoch 00035: val_loss did not improve from 0.09359
# Epoch 36/67
# 344/344 [==============================] - 346s 1s/step - loss: 0.1237 - accuracy: 0.9564 - val_loss: 0.1037 - val_accuracy: 0.9668
#
# Epoch 00036: val_loss did not improve from 0.09359
# Epoch 37/67
# 344/344 [==============================] - 346s 1s/step - loss: 0.1128 - accuracy: 0.9580 - val_loss: 0.1142 - val_accuracy: 0.9584
#
# Epoch 00037: val_loss did not improve from 0.09359
# Epoch 38/67
# 344/344 [==============================] - 346s 1s/step - loss: 0.1130 - accuracy: 0.9581 - val_loss: 0.1010 - val_accuracy: 0.9674
#
# Epoch 00038: val_loss did not improve from 0.09359
# Epoch 39/67
# 344/344 [==============================] - 346s 1s/step - loss: 0.1115 - accuracy: 0.9616 - val_loss: 0.0959 - val_accuracy: 0.9685
#
# Epoch 00039: val_loss did not improve from 0.09359
# Epoch 40/67
# 344/344 [==============================] - 346s 1s/step - loss: 0.1078 - accuracy: 0.9618 - val_loss: 0.1034 - val_accuracy: 0.9641
#
# Epoch 00040: val_loss did not improve from 0.09359
# Epoch 41/67
# 344/344 [==============================] - 345s 1s/step - loss: 0.1088 - accuracy: 0.9611 - val_loss: 0.0923 - val_accuracy: 0.9671
#
# Epoch 00041: val_loss improved from 0.09359 to 0.09230, saving model to checkpoints-warmup.hdf5
# Epoch 42/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.1066 - accuracy: 0.9628 - val_loss: 0.1307 - val_accuracy: 0.9530
#
# Epoch 00042: val_loss did not improve from 0.09230
# Epoch 43/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.1000 - accuracy: 0.9651 - val_loss: 0.1014 - val_accuracy: 0.9617
#
# Epoch 00043: val_loss did not improve from 0.09230
# Epoch 44/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1097 - accuracy: 0.9611 - val_loss: 0.0774 - val_accuracy: 0.9744
#
# Epoch 00044: val_loss improved from 0.09230 to 0.07736, saving model to checkpoints-warmup.hdf5
# Epoch 45/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1056 - accuracy: 0.9618 - val_loss: 0.0874 - val_accuracy: 0.9712
#
# Epoch 00045: val_loss did not improve from 0.07736
# Epoch 46/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.0975 - accuracy: 0.9661 - val_loss: 0.0974 - val_accuracy: 0.9641
#
# Epoch 00046: val_loss did not improve from 0.07736
# Epoch 47/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.0896 - accuracy: 0.9696 - val_loss: 0.0916 - val_accuracy: 0.9674
#
# Epoch 00047: val_loss did not improve from 0.07736
# Epoch 48/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.1105 - accuracy: 0.9636 - val_loss: 0.0959 - val_accuracy: 0.9652
#
# Epoch 00048: val_loss did not improve from 0.07736
# Epoch 49/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.0953 - accuracy: 0.9662 - val_loss: 0.0991 - val_accuracy: 0.9641
#
# Epoch 00049: val_loss did not improve from 0.07736
# Epoch 50/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.0787 - accuracy: 0.9715 - val_loss: 0.1444 - val_accuracy: 0.9503
#
# Epoch 00050: val_loss did not improve from 0.07736
# Epoch 51/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.0961 - accuracy: 0.9674 - val_loss: 0.1202 - val_accuracy: 0.9587
#
# Epoch 00051: val_loss did not improve from 0.07736
# Epoch 52/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.0921 - accuracy: 0.9683 - val_loss: 0.1098 - val_accuracy: 0.9630
#
# Epoch 00052: val_loss did not improve from 0.07736
# Epoch 53/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.0873 - accuracy: 0.9706 - val_loss: 0.0975 - val_accuracy: 0.9696
#
# Epoch 00053: val_loss did not improve from 0.07736
# Epoch 54/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.0919 - accuracy: 0.9699 - val_loss: 0.0941 - val_accuracy: 0.9677
#
# Epoch 00054: val_loss did not improve from 0.07736
# Epoch 55/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.0884 - accuracy: 0.9699 - val_loss: 0.0721 - val_accuracy: 0.9761
#
# Epoch 00055: val_loss improved from 0.07736 to 0.07206, saving model to checkpoints-warmup.hdf5
# Epoch 56/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.0822 - accuracy: 0.9715 - val_loss: 0.1439 - val_accuracy: 0.9573
#
# Epoch 00056: val_loss did not improve from 0.07206
# Epoch 57/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.0872 - accuracy: 0.9687 - val_loss: 0.0735 - val_accuracy: 0.9750
#
# Epoch 00057: val_loss did not improve from 0.07206
# Epoch 58/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.0798 - accuracy: 0.9716 - val_loss: 0.0739 - val_accuracy: 0.9742
#
# Epoch 00058: val_loss did not improve from 0.07206
# Epoch 59/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.0786 - accuracy: 0.9724 - val_loss: 0.0920 - val_accuracy: 0.9717
#
# Epoch 00059: val_loss did not improve from 0.07206
# Epoch 60/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.0787 - accuracy: 0.9704 - val_loss: 0.0719 - val_accuracy: 0.9772
#
# Epoch 00060: val_loss improved from 0.07206 to 0.07187, saving model to checkpoints-warmup.hdf5
# Epoch 61/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.0810 - accuracy: 0.9725 - val_loss: 0.0729 - val_accuracy: 0.9764
#
# Epoch 00061: val_loss did not improve from 0.07187
# Epoch 62/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.0858 - accuracy: 0.9724 - val_loss: 0.0843 - val_accuracy: 0.9698
#
# Epoch 00062: val_loss did not improve from 0.07187
# Epoch 63/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.0795 - accuracy: 0.9723 - val_loss: 0.0758 - val_accuracy: 0.9739
#
# Epoch 00063: val_loss did not improve from 0.07187
# Epoch 64/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.0717 - accuracy: 0.9752 - val_loss: 0.0677 - val_accuracy: 0.9785
#
# Epoch 00064: val_loss improved from 0.07187 to 0.06766, saving model to checkpoints-warmup.hdf5
# Epoch 65/67
# 344/344 [==============================] - 347s 1s/step - loss: 0.0741 - accuracy: 0.9738 - val_loss: 0.0780 - val_accuracy: 0.9739
#
# Epoch 00065: val_loss did not improve from 0.06766
# Epoch 66/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.0721 - accuracy: 0.9749 - val_loss: 0.1265 - val_accuracy: 0.9571
#
# Epoch 00066: val_loss did not improve from 0.06766
# Epoch 67/67
# 344/344 [==============================] - 348s 1s/step - loss: 0.0761 - accuracy: 0.9740 - val_loss: 0.1320 - val_accuracy: 0.9557
#
# Epoch 00067: val_loss did not improve from 0.06766

# %% [markdown]
# # Evaluate with 20% test set from same dataset

# %%
from sklearn.metrics import classification_report

print("[INFO] evaluating after initialization...")
predictions = model.predict(test_x,batch_size=32)
print(classification_report(test_y.argmax(axis =1),
                            predictions.argmax(axis =1),target_names=class_names))
# Out:
# [INFO] evaluating after initialization...
#                            precision    recall  f1-score   support
#
#         ___Bacterial_spot       0.95      0.97      0.96       523
#           ___Early_blight       0.80      0.89      0.84       251
#            ___Late_blight       0.99      0.86      0.92       480
#              ___Leaf_Mold       0.95      0.96      0.96       244
#           ___Mosaic_Virus       0.82      1.00      0.90        76
#            ___Target_Spot       0.91      0.97      0.94       345
# ___Yellow_Leaf_Curl_Virus       0.99      0.98      0.99      1345
#                ___healthy       0.99      0.99      0.99       415
#
#               avg / total       0.96      0.96      0.96      3679
