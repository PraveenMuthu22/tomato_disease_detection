# %% [markdown]
# # Arguments

# %%
num_of_epochs = 25
batch_size = 32
dataset_name = 'tomato-dataset'
dataset_path = '../datasets/' + dataset_name
model_save_path = 'model.h5'

checkpoint_path = 'checkpoints.hdf5'

input_width = 224
input_height = 224
input_depth = 3

# Get classes
import os
import re
classes = os.listdir(dataset_path)
class_names = []

for i in classes:
    if(re.search("Tomato___", i)):
        class_names.append(i)
    
print('Classes: ', class_names)
print(len(class_names))
# Out:
# Classes:  ['Tomato___Tomato_mosaic_virus', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Bacterial_spot', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___healthy', 'Tomato___Septoria_leaf_spot', 'Tomato___Two-spotted_spider_mite']
# 10

# %% [markdown]
# # Load model

# %%
from keras.applications import VGG16
from keras.utils.vis_utils import plot_model
from keras.layers import Input



# Load pretrianed VGG model with FC layers removed
# explicitly deﬁne the input_tensor to be 224×224×3 pixels
base_model = VGG16( weights=None,
                    include_top=False,
                    input_tensor=Input(shape = (input_width,input_height, input_depth)))

plot_save_path = 'diagram-top-removed.png'
# plot_model(base_model, to_file=plot_save_path, show_shapes=True)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Custom FC layer

# %%
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense

head_model = base_model.output
head_model = Flatten(name='flatten')(head_model)
head_model = Dense(4096,activation='relu')(head_model)
head_model = Dense(4096,activation='relu')(head_model)
# Add a softmaxc layer
head_model = Dense(len(class_names),activation='softmax')(head_model)

# %% [markdown]
# # Attach custom head to model

# %%
from keras.models import Model


# place the head FC model on top of the base model 
model = Model(inputs=base_model.input, outputs = head_model)

# freeze weights in base model
for layer in base_model.layers:
    layer.trainable = False

plot_save_path = 'diagram-head-attached.png'
# plot_model(model, to_file=plot_save_path, show_shapes=True)

# %% [markdown]
# # Compile model

# %%
from keras.optimizers import SGD

# Build the model from the new
print("[INFO] re-compiling model ...")
opt = SGD(lr=0.001, momentum=0.09)

model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])
# Since we only train the new fully connected layer, we do a few iterations
print("[INFO] training head...")
# Out:
# [INFO] re-compiling model ...
# [INFO] training head...

# %% [markdown]
# # Load data

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.preprocessing.image   import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.layers import Input
from keras.models import Model
from keras .applications import VGG16
from keras.optimizers import SGD
from keras.models import Model
from imutils import paths
import numpy as np
import os

import sys
sys.path.append('..')

from utils.preprocessors.aspect_aware_preprocessor import AspectAwarePreprocessor
from utils.preprocessors.image_to_array_preprocessor import ImageToArrayPreprocessor
from utils.io.simple_dataset_loader import SimpleDatasetLoader

# construct the image generator for data augmentation
aug = ImageDataGenerator(   rotation_range=30,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            shear_range=0.2,
                            zoom_range=0.2,
                            horizontal_flip=True,
                            fill_mode='nearest')

# Load image paths
print("[INFO] loading images...")
image_paths = list(paths.list_images(dataset_path))

# Initial image preprocessing
aap = AspectAwarePreprocessor(input_width, input_height)
iap= ImageToArrayPreprocessor()

#Load image data and perform image data preprocessing
sdl = SimpleDatasetLoader(preprocessors=[aap,iap])
(data,labels)  = sdl.load(image_paths,verbose=500)
data = data.astype("float") / 255.0


# train test split
(train_x,test_x,train_y,test_y) = train_test_split(data,labels,test_size=0.25,random_state=42)

# convert the labels from integers to vectors
train_y = LabelBinarizer().fit_transform(train_y)
test_y = LabelBinarizer().fit_transform(test_y)
# Out:
# [INFO] loading images...
# [INFO]: Processed 500/18160
# [INFO]: Processed 1000/18160
# [INFO]: Processed 1500/18160
# [INFO]: Processed 2000/18160
# [INFO]: Processed 2500/18160
# [INFO]: Processed 3000/18160
# [INFO]: Processed 3500/18160
# [INFO]: Processed 4000/18160
# [INFO]: Processed 4500/18160
# [INFO]: Processed 5000/18160
# [INFO]: Processed 5500/18160
# [INFO]: Processed 6000/18160
# [INFO]: Processed 6500/18160
# [INFO]: Processed 7000/18160
# [INFO]: Processed 7500/18160
# [INFO]: Processed 8000/18160
# [INFO]: Processed 8500/18160
# [INFO]: Processed 9000/18160
# [INFO]: Processed 9500/18160
# [INFO]: Processed 10000/18160
# [INFO]: Processed 10500/18160
# [INFO]: Processed 11000/18160
# [INFO]: Processed 11500/18160
# [INFO]: Processed 12000/18160
# [INFO]: Processed 12500/18160
# [INFO]: Processed 13000/18160
# [INFO]: Processed 13500/18160
# [INFO]: Processed 14000/18160
# [INFO]: Processed 14500/18160
# [INFO]: Processed 15000/18160
# [INFO]: Processed 15500/18160
# [INFO]: Processed 16000/18160
# [INFO]: Processed 16500/18160
# [INFO]: Processed 17000/18160
# [INFO]: Processed 17500/18160
# [INFO]: Processed 18000/18160

# %% [markdown]
# # Checkpoints

# %%
from keras.callbacks import ModelCheckpoint


checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', mode='min', 
save_best_only=True, verbose=1)

callbacks = [checkpoint]

# %%
#load checkpoints if existing

import os

epochs_done = 0
num_of_epochs = 100

if(os.path.exists(checkpoint_path)):
    model.load_weights(checkpoint_path)
    num_of_epochs = num_of_epochs - epochs_done

# %% [markdown]
# # Training monitor

# %%
from utils.callbacks.training_monitor import TrainingMonitor
import pathlib
import json
import os

fig_path = "plot"
json_path = "values.json"
values_path = 'values.json'
start_epoch = 0

last_epoch = None
last_improved_epoch = None
load_from_early_epoch = False

if(os.path.exists(values_path) and load_from_early_epoch):
    with open(values_path) as file_content:
        data = json.load(file_content)
        start_epoch = len(data['val_accuracy']) - (last_epoch - last_improved_epoch)
        print('loaded from early epoch')



callbacks.append(TrainingMonitor(fig_path, json_path, start_epoch))

# %% [markdown]
# # Perform training

# %%
# num_of_epochs = 15

model.fit_generator(
    aug.flow(train_x,train_y, batch_size = 32),
             validation_data = (test_x,test_y),
             epochs=num_of_epochs,
             steps_per_epoch = len(train_x) //32,
             verbose = 1,
             callbacks=callbacks)
# Out:
# Epoch 1/100
# 425/425 [==============================] - 209s 492ms/step - loss: 2.2765 - accuracy: 0.2938 - val_loss: 2.2548 - val_accuracy: 0.2985
#
# Epoch 00001: val_loss improved from inf to 2.25479, saving model to checkpoints.hdf5
# Epoch 2/100
# 425/425 [==============================] - 210s 493ms/step - loss: 2.2375 - accuracy: 0.2933 - val_loss: 2.2185 - val_accuracy: 0.2985
#
# Epoch 00002: val_loss improved from 2.25479 to 2.21849, saving model to checkpoints.hdf5
# Epoch 3/100
# 425/425 [==============================] - 204s 479ms/step - loss: 2.2046 - accuracy: 0.2947 - val_loss: 2.1885 - val_accuracy: 0.2985
#
# Epoch 00003: val_loss improved from 2.21849 to 2.18846, saving model to checkpoints.hdf5
# Epoch 4/100
# 425/425 [==============================] - 208s 490ms/step - loss: 2.1792 - accuracy: 0.2933 - val_loss: 2.1649 - val_accuracy: 0.2985
#
# Epoch 00004: val_loss improved from 2.18846 to 2.16492, saving model to checkpoints.hdf5
# Epoch 5/100
# 425/425 [==============================] - 210s 494ms/step - loss: 2.1586 - accuracy: 0.2942 - val_loss: 2.1469 - val_accuracy: 0.2985
#
# Epoch 00005: val_loss improved from 2.16492 to 2.14694, saving model to checkpoints.hdf5
# Epoch 6/100
# 425/425 [==============================] - 208s 489ms/step - loss: 2.1437 - accuracy: 0.2942 - val_loss: 2.1339 - val_accuracy: 0.2985
#
# Epoch 00006: val_loss improved from 2.14694 to 2.13389, saving model to checkpoints.hdf5
# Epoch 7/100
# 425/425 [==============================] - 208s 490ms/step - loss: 2.1331 - accuracy: 0.2938 - val_loss: 2.1248 - val_accuracy: 0.2985
#
# Epoch 00007: val_loss improved from 2.13389 to 2.12478, saving model to checkpoints.hdf5
# Epoch 8/100
# 425/425 [==============================] - 210s 494ms/step - loss: 2.1264 - accuracy: 0.2933 - val_loss: 2.1185 - val_accuracy: 0.2985
#
# Epoch 00008: val_loss improved from 2.12478 to 2.11851, saving model to checkpoints.hdf5
# Epoch 9/100
# 425/425 [==============================] - 209s 492ms/step - loss: 2.1199 - accuracy: 0.2945 - val_loss: 2.1140 - val_accuracy: 0.2985
#
# Epoch 00009: val_loss improved from 2.11851 to 2.11405, saving model to checkpoints.hdf5
# Epoch 10/100
# 425/425 [==============================] - 208s 489ms/step - loss: 2.1176 - accuracy: 0.2935 - val_loss: 2.1109 - val_accuracy: 0.2985
#
# Epoch 00010: val_loss improved from 2.11405 to 2.11092, saving model to checkpoints.hdf5
# Epoch 11/100
# 425/425 [==============================] - 204s 481ms/step - loss: 2.1131 - accuracy: 0.2947 - val_loss: 2.1085 - val_accuracy: 0.2985
#
# Epoch 00011: val_loss improved from 2.11092 to 2.10854, saving model to checkpoints.hdf5
# Epoch 12/100
# 425/425 [==============================] - 202s 474ms/step - loss: 2.1136 - accuracy: 0.2932 - val_loss: 2.1068 - val_accuracy: 0.2985
#
# Epoch 00012: val_loss improved from 2.10854 to 2.10676, saving model to checkpoints.hdf5
# Epoch 13/100
# 425/425 [==============================] - 202s 475ms/step - loss: 2.1117 - accuracy: 0.2932 - val_loss: 2.1053 - val_accuracy: 0.2985
#
# Epoch 00013: val_loss improved from 2.10676 to 2.10531, saving model to checkpoints.hdf5
# Epoch 14/100
# 425/425 [==============================] - 201s 473ms/step - loss: 2.1086 - accuracy: 0.2947 - val_loss: 2.1041 - val_accuracy: 0.2985
#
# Epoch 00014: val_loss improved from 2.10531 to 2.10412, saving model to checkpoints.hdf5
# Epoch 15/100
# 425/425 [==============================] - 200s 471ms/step - loss: 2.1099 - accuracy: 0.2926 - val_loss: 2.1031 - val_accuracy: 0.2985
#
# Epoch 00015: val_loss improved from 2.10412 to 2.10314, saving model to checkpoints.hdf5
# Epoch 16/100
# 425/425 [==============================] - 197s 464ms/step - loss: 2.1062 - accuracy: 0.2948 - val_loss: 2.1023 - val_accuracy: 0.2985
#
# Epoch 00016: val_loss improved from 2.10314 to 2.10229, saving model to checkpoints.hdf5
# Epoch 17/100
# 425/425 [==============================] - 197s 463ms/step - loss: 2.1049 - accuracy: 0.2947 - val_loss: 2.1016 - val_accuracy: 0.2985
#
# Epoch 00017: val_loss improved from 2.10229 to 2.10156, saving model to checkpoints.hdf5
# Epoch 18/100
# 425/425 [==============================] - 197s 463ms/step - loss: 2.1068 - accuracy: 0.2929 - val_loss: 2.1009 - val_accuracy: 0.2985
#
# Epoch 00018: val_loss improved from 2.10156 to 2.10094, saving model to checkpoints.hdf5
# Epoch 19/100
# 425/425 [==============================] - 197s 464ms/step - loss: 2.1074 - accuracy: 0.2928 - val_loss: 2.1005 - val_accuracy: 0.2985
#
# Epoch 00019: val_loss improved from 2.10094 to 2.10045, saving model to checkpoints.hdf5
# Epoch 20/100
# 425/425 [==============================] - 198s 465ms/step - loss: 2.1049 - accuracy: 0.2941 - val_loss: 2.1000 - val_accuracy: 0.2985
#
# Epoch 00020: val_loss improved from 2.10045 to 2.10000, saving model to checkpoints.hdf5
# Epoch 21/100
# 425/425 [==============================] - 199s 468ms/step - loss: 2.1020 - accuracy: 0.2951 - val_loss: 2.0996 - val_accuracy: 0.2985
#
# Epoch 00021: val_loss improved from 2.10000 to 2.09958, saving model to checkpoints.hdf5
# Epoch 22/100
# 425/425 [==============================] - 200s 470ms/step - loss: 2.1048 - accuracy: 0.2933 - val_loss: 2.0993 - val_accuracy: 0.2985
#
# Epoch 00022: val_loss improved from 2.09958 to 2.09926, saving model to checkpoints.hdf5
# Epoch 23/100
# 425/425 [==============================] - 199s 469ms/step - loss: 2.1059 - accuracy: 0.2926 - val_loss: 2.0990 - val_accuracy: 0.2985
#
# Epoch 00023: val_loss improved from 2.09926 to 2.09898, saving model to checkpoints.hdf5
# Epoch 24/100
# 425/425 [==============================] - 201s 472ms/step - loss: 2.1012 - accuracy: 0.2956 - val_loss: 2.0987 - val_accuracy: 0.2985
#
# Epoch 00024: val_loss improved from 2.09898 to 2.09869, saving model to checkpoints.hdf5
# Epoch 25/100
# 425/425 [==============================] - 200s 471ms/step - loss: 2.1045 - accuracy: 0.2931 - val_loss: 2.0985 - val_accuracy: 0.2985
#
# Epoch 00025: val_loss improved from 2.09869 to 2.09849, saving model to checkpoints.hdf5
# Epoch 26/100
# 425/425 [==============================] - 199s 468ms/step - loss: 2.1033 - accuracy: 0.2933 - val_loss: 2.0983 - val_accuracy: 0.2985
#
# Epoch 00026: val_loss improved from 2.09849 to 2.09828, saving model to checkpoints.hdf5
# Epoch 27/100
# 425/425 [==============================] - 198s 466ms/step - loss: 2.1012 - accuracy: 0.2951 - val_loss: 2.0981 - val_accuracy: 0.2985
#
# Epoch 00027: val_loss improved from 2.09828 to 2.09808, saving model to checkpoints.hdf5
# Epoch 28/100
# 425/425 [==============================] - 199s 468ms/step - loss: 2.1045 - accuracy: 0.2916 - val_loss: 2.0979 - val_accuracy: 0.2985
#
# Epoch 00028: val_loss improved from 2.09808 to 2.09793, saving model to checkpoints.hdf5
# Epoch 29/100
# 425/425 [==============================] - 203s 477ms/step - loss: 2.1027 - accuracy: 0.2936 - val_loss: 2.0978 - val_accuracy: 0.2985
#
# Epoch 00029: val_loss improved from 2.09793 to 2.09780, saving model to checkpoints.hdf5
# Epoch 30/100
# 425/425 [==============================] - 202s 475ms/step - loss: 2.1001 - accuracy: 0.2947 - val_loss: 2.0977 - val_accuracy: 0.2985
#
# Epoch 00030: val_loss improved from 2.09780 to 2.09767, saving model to checkpoints.hdf5
# Epoch 31/100
# 425/425 [==============================] - 204s 481ms/step - loss: 2.1021 - accuracy: 0.2946 - val_loss: 2.0976 - val_accuracy: 0.2985
#
# Epoch 00031: val_loss improved from 2.09767 to 2.09757, saving model to checkpoints.hdf5
# Epoch 32/100
# 425/425 [==============================] - 205s 482ms/step - loss: 2.1033 - accuracy: 0.2933 - val_loss: 2.0975 - val_accuracy: 0.2985
#
# Epoch 00032: val_loss improved from 2.09757 to 2.09747, saving model to checkpoints.hdf5
# Epoch 33/100
# 425/425 [==============================] - 200s 472ms/step - loss: 2.1010 - accuracy: 0.2930 - val_loss: 2.0974 - val_accuracy: 0.2985
#
# Epoch 00033: val_loss improved from 2.09747 to 2.09736, saving model to checkpoints.hdf5
# Epoch 34/100
# 425/425 [==============================] - 205s 482ms/step - loss: 2.1051 - accuracy: 0.2911 - val_loss: 2.0973 - val_accuracy: 0.2985
#
# Epoch 00034: val_loss improved from 2.09736 to 2.09729, saving model to checkpoints.hdf5
# Epoch 35/100
# 425/425 [==============================] - 202s 476ms/step - loss: 2.0989 - accuracy: 0.2973 - val_loss: 2.0972 - val_accuracy: 0.2985
#
# Epoch 00035: val_loss improved from 2.09729 to 2.09720, saving model to checkpoints.hdf5
# Epoch 36/100
# 425/425 [==============================] - 205s 483ms/step - loss: 2.0971 - accuracy: 0.2962 - val_loss: 2.0971 - val_accuracy: 0.2985
#
# Epoch 00036: val_loss improved from 2.09720 to 2.09709, saving model to checkpoints.hdf5
# Epoch 37/100
# 425/425 [==============================] - 204s 480ms/step - loss: 2.1039 - accuracy: 0.2922 - val_loss: 2.0971 - val_accuracy: 0.2985
#
# Epoch 00037: val_loss improved from 2.09709 to 2.09706, saving model to checkpoints.hdf5
# Epoch 38/100
# 425/425 [==============================] - 198s 467ms/step - loss: 2.1012 - accuracy: 0.2942 - val_loss: 2.0970 - val_accuracy: 0.2985
#
# Epoch 00038: val_loss improved from 2.09706 to 2.09698, saving model to checkpoints.hdf5
# Epoch 39/100
# 425/425 [==============================] - 200s 469ms/step - loss: 2.1009 - accuracy: 0.2929 - val_loss: 2.0969 - val_accuracy: 0.2985
#
# Epoch 00039: val_loss improved from 2.09698 to 2.09694, saving model to checkpoints.hdf5
# Epoch 40/100
# 425/425 [==============================] - 205s 483ms/step - loss: 2.1055 - accuracy: 0.2909 - val_loss: 2.0969 - val_accuracy: 0.2985
#
# Epoch 00040: val_loss improved from 2.09694 to 2.09693, saving model to checkpoints.hdf5
# Epoch 41/100
# 425/425 [==============================] - 206s 485ms/step - loss: 2.0971 - accuracy: 0.2967 - val_loss: 2.0968 - val_accuracy: 0.2985
#
# Epoch 00041: val_loss improved from 2.09693 to 2.09685, saving model to checkpoints.hdf5
# Epoch 42/100
# 425/425 [==============================] - 208s 490ms/step - loss: 2.1030 - accuracy: 0.2936 - val_loss: 2.0968 - val_accuracy: 0.2985
#
# Epoch 00042: val_loss improved from 2.09685 to 2.09681, saving model to checkpoints.hdf5
# Epoch 43/100
# 425/425 [==============================] - 208s 489ms/step - loss: 2.0969 - accuracy: 0.2957 - val_loss: 2.0968 - val_accuracy: 0.2985
#
# Epoch 00043: val_loss improved from 2.09681 to 2.09676, saving model to checkpoints.hdf5
# Epoch 44/100
# 425/425 [==============================] - 213s 501ms/step - loss: 2.1035 - accuracy: 0.2934 - val_loss: 2.0967 - val_accuracy: 0.2985
#
# Epoch 00044: val_loss improved from 2.09676 to 2.09672, saving model to checkpoints.hdf5
# Epoch 45/100
# 425/425 [==============================] - 205s 482ms/step - loss: 2.0979 - accuracy: 0.2952 - val_loss: 2.0967 - val_accuracy: 0.2985
#
# Epoch 00045: val_loss improved from 2.09672 to 2.09669, saving model to checkpoints.hdf5
# Epoch 46/100
# 425/425 [==============================] - 208s 491ms/step - loss: 2.1068 - accuracy: 0.2904 - val_loss: 2.0967 - val_accuracy: 0.2985
#
# Epoch 00046: val_loss improved from 2.09669 to 2.09669, saving model to checkpoints.hdf5
# Epoch 47/100
# 425/425 [==============================] - 209s 492ms/step - loss: 2.0984 - accuracy: 0.2940 - val_loss: 2.0967 - val_accuracy: 0.2985
#
# Epoch 00047: val_loss improved from 2.09669 to 2.09666, saving model to checkpoints.hdf5
# Epoch 48/100
# 425/425 [==============================] - 208s 490ms/step - loss: 2.1021 - accuracy: 0.2948 - val_loss: 2.0966 - val_accuracy: 0.2985
#
# Epoch 00048: val_loss improved from 2.09666 to 2.09661, saving model to checkpoints.hdf5
# Epoch 49/100
# 425/425 [==============================] - 207s 487ms/step - loss: 2.0990 - accuracy: 0.2943 - val_loss: 2.0966 - val_accuracy: 0.2985
#
# Epoch 00049: val_loss improved from 2.09661 to 2.09656, saving model to checkpoints.hdf5
# Epoch 50/100
# 425/425 [==============================] - 210s 494ms/step - loss: 2.0993 - accuracy: 0.2950 - val_loss: 2.0965 - val_accuracy: 0.2985
#
# Epoch 00050: val_loss improved from 2.09656 to 2.09653, saving model to checkpoints.hdf5
# Epoch 51/100
# 425/425 [==============================] - 210s 494ms/step - loss: 2.1032 - accuracy: 0.2919 - val_loss: 2.0965 - val_accuracy: 0.2985
#
# Epoch 00051: val_loss did not improve from 2.09653
# Epoch 52/100
# 425/425 [==============================] - 204s 480ms/step - loss: 2.0988 - accuracy: 0.2942 - val_loss: 2.0965 - val_accuracy: 0.2985
#
# Epoch 00052: val_loss improved from 2.09653 to 2.09651, saving model to checkpoints.hdf5
# Epoch 53/100
# 425/425 [==============================] - 207s 486ms/step - loss: 2.1025 - accuracy: 0.2935 - val_loss: 2.0965 - val_accuracy: 0.2985
#
# Epoch 00053: val_loss improved from 2.09651 to 2.09648, saving model to checkpoints.hdf5
# Epoch 54/100
# 425/425 [==============================] - 209s 491ms/step - loss: 2.1011 - accuracy: 0.2936 - val_loss: 2.0964 - val_accuracy: 0.2985
#
# Epoch 00054: val_loss improved from 2.09648 to 2.09644, saving model to checkpoints.hdf5
# Epoch 55/100
# 425/425 [==============================] - 214s 503ms/step - loss: 2.0988 - accuracy: 0.2950 - val_loss: 2.0964 - val_accuracy: 0.2985
#
# Epoch 00055: val_loss improved from 2.09644 to 2.09642, saving model to checkpoints.hdf5
# Epoch 56/100
# 425/425 [==============================] - 210s 495ms/step - loss: 2.0966 - accuracy: 0.2956 - val_loss: 2.0964 - val_accuracy: 0.2985
#
# Epoch 00056: val_loss improved from 2.09642 to 2.09637, saving model to checkpoints.hdf5
# Epoch 57/100
# 425/425 [==============================] - 210s 494ms/step - loss: 2.1044 - accuracy: 0.2905 - val_loss: 2.0964 - val_accuracy: 0.2985
#
# Epoch 00057: val_loss did not improve from 2.09637
# Epoch 58/100
# 425/425 [==============================] - 203s 477ms/step - loss: 2.1007 - accuracy: 0.2953 - val_loss: 2.0964 - val_accuracy: 0.2985
#
# Epoch 00058: val_loss improved from 2.09637 to 2.09636, saving model to checkpoints.hdf5
# Epoch 59/100
# 425/425 [==============================] - 206s 485ms/step - loss: 2.0993 - accuracy: 0.2942 - val_loss: 2.0963 - val_accuracy: 0.2985
#
# Epoch 00059: val_loss improved from 2.09636 to 2.09634, saving model to checkpoints.hdf5
# Epoch 60/100
# 425/425 [==============================] - 208s 490ms/step - loss: 2.1015 - accuracy: 0.2930 - val_loss: 2.0963 - val_accuracy: 0.2985
#
# Epoch 00060: val_loss improved from 2.09634 to 2.09632, saving model to checkpoints.hdf5
# Epoch 61/100
# 425/425 [==============================] - 207s 486ms/step - loss: 2.0975 - accuracy: 0.2947 - val_loss: 2.0963 - val_accuracy: 0.2985
#
# Epoch 00061: val_loss improved from 2.09632 to 2.09629, saving model to checkpoints.hdf5
# Epoch 62/100
# 425/425 [==============================] - 205s 482ms/step - loss: 2.1042 - accuracy: 0.2926 - val_loss: 2.0963 - val_accuracy: 0.2985
#
# Epoch 00062: val_loss improved from 2.09629 to 2.09627, saving model to checkpoints.hdf5
# Epoch 63/100
# 425/425 [==============================] - 208s 488ms/step - loss: 2.0980 - accuracy: 0.2943 - val_loss: 2.0962 - val_accuracy: 0.2985
#
# Epoch 00063: val_loss improved from 2.09627 to 2.09624, saving model to checkpoints.hdf5
# Epoch 64/100
# 425/425 [==============================] - 204s 480ms/step - loss: 2.1034 - accuracy: 0.2922 - val_loss: 2.0963 - val_accuracy: 0.2985
#
# Epoch 00064: val_loss did not improve from 2.09624
# Epoch 65/100
# 425/425 [==============================] - 208s 490ms/step - loss: 2.0995 - accuracy: 0.2954 - val_loss: 2.0962 - val_accuracy: 0.2985
#
# Epoch 00065: val_loss improved from 2.09624 to 2.09622, saving model to checkpoints.hdf5
# Epoch 66/100
# 425/425 [==============================] - 210s 495ms/step - loss: 2.0997 - accuracy: 0.2927 - val_loss: 2.0962 - val_accuracy: 0.2985
#
# Epoch 00066: val_loss improved from 2.09622 to 2.09621, saving model to checkpoints.hdf5
# Epoch 67/100
# 425/425 [==============================] - 209s 491ms/step - loss: 2.1000 - accuracy: 0.2955 - val_loss: 2.0962 - val_accuracy: 0.2985
#
# Epoch 00067: val_loss improved from 2.09621 to 2.09617, saving model to checkpoints.hdf5
# Epoch 68/100
# 425/425 [==============================] - 201s 474ms/step - loss: 2.1016 - accuracy: 0.2912 - val_loss: 2.0962 - val_accuracy: 0.2985
#
# Epoch 00068: val_loss improved from 2.09617 to 2.09617, saving model to checkpoints.hdf5
# Epoch 69/100
# 425/425 [==============================] - 206s 484ms/step - loss: 2.1021 - accuracy: 0.2932 - val_loss: 2.0962 - val_accuracy: 0.2985
#
# Epoch 00069: val_loss improved from 2.09617 to 2.09616, saving model to checkpoints.hdf5
# Epoch 70/100
# 425/425 [==============================] - 211s 495ms/step - loss: 2.0972 - accuracy: 0.2960 - val_loss: 2.0961 - val_accuracy: 0.2985
#
# Epoch 00070: val_loss improved from 2.09616 to 2.09612, saving model to checkpoints.hdf5
# Epoch 71/100
# 425/425 [==============================] - 209s 492ms/step - loss: 2.0977 - accuracy: 0.2965 - val_loss: 2.0961 - val_accuracy: 0.2985
#
# Epoch 00071: val_loss improved from 2.09612 to 2.09607, saving model to checkpoints.hdf5
# Epoch 72/100
# 425/425 [==============================] - 216s 509ms/step - loss: 2.1043 - accuracy: 0.2894 - val_loss: 2.0961 - val_accuracy: 0.2985
#
# Epoch 00072: val_loss did not improve from 2.09607
# Epoch 73/100
# 425/425 [==============================] - 214s 504ms/step - loss: 2.0992 - accuracy: 0.2955 - val_loss: 2.0961 - val_accuracy: 0.2985
#
# Epoch 00073: val_loss did not improve from 2.09607
# Epoch 74/100
# 425/425 [==============================] - 215s 506ms/step - loss: 2.0965 - accuracy: 0.2956 - val_loss: 2.0960 - val_accuracy: 0.2985
#
# Epoch 00074: val_loss improved from 2.09607 to 2.09602, saving model to checkpoints.hdf5
# Epoch 75/100
# 425/425 [==============================] - 215s 506ms/step - loss: 2.1038 - accuracy: 0.2922 - val_loss: 2.0960 - val_accuracy: 0.2985
#
# Epoch 00075: val_loss did not improve from 2.09602
# Epoch 76/100
# 425/425 [==============================] - 214s 504ms/step - loss: 2.1001 - accuracy: 0.2938 - val_loss: 2.0960 - val_accuracy: 0.2985
#
# Epoch 00076: val_loss improved from 2.09602 to 2.09601, saving model to checkpoints.hdf5
# Epoch 77/100
# 425/425 [==============================] - 212s 498ms/step - loss: 2.0961 - accuracy: 0.2953 - val_loss: 2.0960 - val_accuracy: 0.2985
#
# Epoch 00077: val_loss improved from 2.09601 to 2.09601, saving model to checkpoints.hdf5
# Epoch 78/100
# 425/425 [==============================] - 204s 480ms/step - loss: 2.1044 - accuracy: 0.2923 - val_loss: 2.0960 - val_accuracy: 0.2985
#
# Epoch 00078: val_loss improved from 2.09601 to 2.09598, saving model to checkpoints.hdf5
# Epoch 79/100
# 425/425 [==============================] - 198s 465ms/step - loss: 2.1003 - accuracy: 0.2925 - val_loss: 2.0960 - val_accuracy: 0.2985
#
# Epoch 00079: val_loss improved from 2.09598 to 2.09598, saving model to checkpoints.hdf5
# Epoch 80/100
# 425/425 [==============================] - 196s 462ms/step - loss: 2.0993 - accuracy: 0.2958 - val_loss: 2.0959 - val_accuracy: 0.2985
#
# Epoch 00080: val_loss improved from 2.09598 to 2.09595, saving model to checkpoints.hdf5
# Epoch 81/100
# 425/425 [==============================] - 189s 444ms/step - loss: 2.0997 - accuracy: 0.2936 - val_loss: 2.0959 - val_accuracy: 0.2985
#
# Epoch 00081: val_loss improved from 2.09595 to 2.09593, saving model to checkpoints.hdf5
# Epoch 82/100
# 425/425 [==============================] - 189s 444ms/step - loss: 2.1007 - accuracy: 0.2915 - val_loss: 2.0959 - val_accuracy: 0.2985
#
# Epoch 00082: val_loss did not improve from 2.09593
# Epoch 83/100
# 425/425 [==============================] - 201s 472ms/step - loss: 2.0970 - accuracy: 0.2984 - val_loss: 2.0959 - val_accuracy: 0.2985
#
# Epoch 00083: val_loss improved from 2.09593 to 2.09585, saving model to checkpoints.hdf5
# Epoch 84/100
# 425/425 [==============================] - 201s 472ms/step - loss: 2.1020 - accuracy: 0.2915 - val_loss: 2.0959 - val_accuracy: 0.2985
#
# Epoch 00084: val_loss did not improve from 2.09585
# Epoch 85/100
# 425/425 [==============================] - 199s 467ms/step - loss: 2.1012 - accuracy: 0.2937 - val_loss: 2.0958 - val_accuracy: 0.2985
#
# Epoch 00085: val_loss improved from 2.09585 to 2.09584, saving model to checkpoints.hdf5
# Epoch 86/100
# 425/425 [==============================] - 192s 453ms/step - loss: 2.0988 - accuracy: 0.2947 - val_loss: 2.0958 - val_accuracy: 0.2985
#
# Epoch 00086: val_loss improved from 2.09584 to 2.09581, saving model to checkpoints.hdf5
# Epoch 87/100
# 425/425 [==============================] - 194s 458ms/step - loss: 2.0992 - accuracy: 0.2933 - val_loss: 2.0958 - val_accuracy: 0.2985
#
# Epoch 00087: val_loss improved from 2.09581 to 2.09579, saving model to checkpoints.hdf5
# Epoch 88/100
# 425/425 [==============================] - 207s 488ms/step - loss: 2.0990 - accuracy: 0.2942 - val_loss: 2.0958 - val_accuracy: 0.2985
#
# Epoch 00088: val_loss improved from 2.09579 to 2.09576, saving model to checkpoints.hdf5
# Epoch 89/100
# 425/425 [==============================] - 204s 481ms/step - loss: 2.0993 - accuracy: 0.2948 - val_loss: 2.0958 - val_accuracy: 0.2985
#
# Epoch 00089: val_loss improved from 2.09576 to 2.09575, saving model to checkpoints.hdf5
# Epoch 90/100
# 425/425 [==============================] - 197s 463ms/step - loss: 2.1030 - accuracy: 0.2909 - val_loss: 2.0958 - val_accuracy: 0.2985
#
# Epoch 00090: val_loss improved from 2.09575 to 2.09575, saving model to checkpoints.hdf5
# Epoch 91/100
# 425/425 [==============================] - 200s 471ms/step - loss: 2.0986 - accuracy: 0.2957 - val_loss: 2.0957 - val_accuracy: 0.2985
#
# Epoch 00091: val_loss improved from 2.09575 to 2.09571, saving model to checkpoints.hdf5
# Epoch 92/100
# 425/425 [==============================] - 199s 467ms/step - loss: 2.0999 - accuracy: 0.2925 - val_loss: 2.0957 - val_accuracy: 0.2985
#
# Epoch 00092: val_loss did not improve from 2.09571
# Epoch 93/100
# 425/425 [==============================] - 200s 470ms/step - loss: 2.0975 - accuracy: 0.2952 - val_loss: 2.0957 - val_accuracy: 0.2985
#
# Epoch 00093: val_loss improved from 2.09571 to 2.09568, saving model to checkpoints.hdf5
# Epoch 94/100
# 425/425 [==============================] - 199s 467ms/step - loss: 2.1056 - accuracy: 0.2887 - val_loss: 2.0957 - val_accuracy: 0.2985
#
# Epoch 00094: val_loss did not improve from 2.09568
# Epoch 95/100
# 425/425 [==============================] - 193s 454ms/step - loss: 2.0959 - accuracy: 0.2985 - val_loss: 2.0956 - val_accuracy: 0.2985
#
# Epoch 00095: val_loss improved from 2.09568 to 2.09564, saving model to checkpoints.hdf5
# Epoch 96/100
# 425/425 [==============================] - 202s 476ms/step - loss: 2.1007 - accuracy: 0.2936 - val_loss: 2.0956 - val_accuracy: 0.2985
#
# Epoch 00096: val_loss improved from 2.09564 to 2.09559, saving model to checkpoints.hdf5
# Epoch 97/100
# 425/425 [==============================] - 199s 469ms/step - loss: 2.0992 - accuracy: 0.2942 - val_loss: 2.0956 - val_accuracy: 0.2985
#
# Epoch 00097: val_loss improved from 2.09559 to 2.09559, saving model to checkpoints.hdf5
# Epoch 98/100
# 425/425 [==============================] - 198s 466ms/step - loss: 2.0974 - accuracy: 0.2961 - val_loss: 2.0956 - val_accuracy: 0.2985
#
# Epoch 00098: val_loss improved from 2.09559 to 2.09556, saving model to checkpoints.hdf5
# Epoch 99/100
# 425/425 [==============================] - 204s 480ms/step - loss: 2.1000 - accuracy: 0.2922 - val_loss: 2.0955 - val_accuracy: 0.2985
#
# Epoch 00099: val_loss improved from 2.09556 to 2.09554, saving model to checkpoints.hdf5
# Epoch 100/100
# 425/425 [==============================] - 200s 470ms/step - loss: 2.1013 - accuracy: 0.2928 - val_loss: 2.0955 - val_accuracy: 0.2985
#
# Epoch 00100: val_loss improved from 2.09554 to 2.09553, saving model to checkpoints.hdf5

# %% [markdown]
# # Evaluate after warmup

# %%
from sklearn.metrics import classification_report

print("[INFO] evaluating after initialization...")
predictions = model.predict(test_x,batch_size=32)
print(classification_report(test_y.argmax(axis =1),
                            predictions.argmax(axis =1),target_names=class_names))
# Out:
# [INFO] evaluating after initialization...
#                                         precision    recall  f1-score   support
#
#           Tomato___Tomato_mosaic_virus       0.00      0.00      0.00       532
#                  Tomato___Early_blight       0.00      0.00      0.00       239
#                   Tomato___Late_blight       0.00      0.00      0.00       470
#                     Tomato___Leaf_Mold       0.00      0.00      0.00       238
#                Tomato___Bacterial_spot       0.00      0.00      0.00       435
#                   Tomato___Target_Spot       0.00      0.00      0.00       362
# Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.30      1.00      0.46      1355
#                       Tomato___healthy       0.00      0.00      0.00        98
#            Tomato___Septoria_leaf_spot       0.00      0.00      0.00       414
#       Tomato___Two-spotted_spider_mite       0.00      0.00      0.00       397
#
#                            avg / total       0.09      0.30      0.14      4540
# /usr/local/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
