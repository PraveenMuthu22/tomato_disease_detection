# %% [markdown]
# # Arguments

# %%
num_of_epochs = 25
batch_size = 32
dataset_path_plantvillage = '../datasets/plantvillage'
dataset_path_self = '../datasets/self'
dataset_path_validation = '../datasets/validation'

dataset_paths = [dataset_path_plantvillage, dataset_path_self, dataset_path_validation]

model_save_path = 'model-warmup.h5'

checkpoint_path = 'checkpoints-warmup.hdf5'

input_width = 224
input_height = 224
input_depth = 3

# %% [markdown]
# # Print class names

# %%
# Get classes
import os
import re

class_names = []
class_paths_plant_village = []
class_paths_plant_self = []
class_paths_plant_validation = []

for path in dataset_paths:
    classes = os.listdir(path)
    for i in classes:
        if(re.search('___', i)):
            if(i not in class_names):
                class_names.append(i)
            if(re.search('plantvillage', path)):
                class_paths_plant_village.append(path + '/' + i)
            elif(re.search('self', path)):
                class_paths_plant_self.append(path + '/' + i)
            else:
                class_paths_plant_validation.append(path + '/' + i)

print(class_names)   
print()
print('PlantVillage')
print(class_paths_plant_village) 
print(len(class_paths_plant_village))
print()
print('Self')
print(class_paths_plant_self) 
print(len(class_paths_plant_self))
print()
print('Validation')
print(class_paths_plant_validation) 
print(len(class_paths_plant_validation))
# Out:
# ['___Yellow_Leaf_Curl_Virus', '___Late_blight', '___Early_blight', '___Two-spotted_spider_mite', '___Septoria_leaf_spot', '___Bacterial_spot', '___healthy', '___Target_Spot', '___Mosaic_Virus', '___Leaf_Mold', '___Leaf_miner', '___Appids']
#
# PlantVillage
# ['../datasets/plantvillage/___Yellow_Leaf_Curl_Virus', '../datasets/plantvillage/___Late_blight', '../datasets/plantvillage/___Early_blight', '../datasets/plantvillage/___Two-spotted_spider_mite', '../datasets/plantvillage/___Septoria_leaf_spot', '../datasets/plantvillage/___Bacterial_spot', '../datasets/plantvillage/___healthy', '../datasets/plantvillage/___Target_Spot', '../datasets/plantvillage/___Mosaic_Virus', '../datasets/plantvillage/___Leaf_Mold']
# 10
#
# Self
# ['../datasets/self/___Leaf_miner', '../datasets/self/___Early_blight', '../datasets/self/___Appids']
# 3
#
# Validation
# ['../datasets/validation/___Leaf_miner', '../datasets/validation/___Yellow_Leaf_Curl_Virus', '../datasets/validation/___Late_blight', '../datasets/validation/___Early_blight', '../datasets/validation/___Bacterial_spot', '../datasets/validation/___healthy', '../datasets/validation/___Target_Spot', '../datasets/validation/___Mosaic_Virus', '../datasets/validation/___Leaf_Mold']
# 9

# %% [markdown]
# # Select training classes
#
# early blight in plantVillage dataset replaced by self one

# %%
class_paths_training = ['../datasets/plantvillage/___Late_blight', '../datasets/plantvillage/___Target_Spot', '../datasets/plantvillage/___healthy', '../datasets/plantvillage/___Mosaic_Virus', '../datasets/plantvillage/___Yellow_Leaf_Curl_Virus', '../datasets/plantvillage/___Leaf_Mold', '../datasets/plantvillage/___Bacterial_spot', '../datasets/plantvillage/___Early_blight']

# %% [markdown]
# # Load dataset

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.preprocessing.image   import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.layers import Input
from keras.models import Model
from keras .applications import VGG16
from keras.optimizers import SGD
from keras.models import Model
from imutils import paths
import numpy as np
import os

import sys
sys.path.append('..')

from utils.preprocessors.aspect_aware_preprocessor import AspectAwarePreprocessor
from utils.preprocessors.image_to_array_preprocessor import ImageToArrayPreprocessor
from utils.io.simple_dataset_loader import SimpleDatasetLoader

# construct the image generator for data augmentation
aug = ImageDataGenerator(   rotation_range=30,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            shear_range=0.2,
                            zoom_range=0.2,
                            horizontal_flip=True,
                            fill_mode='nearest')

# Load image paths
image_paths = []
print("[INFO] loading images...")
for path in class_paths_training:
    image_paths.extend(list(paths.list_images(path)))
    
# Get unique classnames

class_names = [pt.split(os.path.sep)[-2] for pt in image_paths]
class_names = [str(x) for x in np.unique(class_names)]

# Initial image preprocessing
aap = AspectAwarePreprocessor(input_width, input_height)
iap= ImageToArrayPreprocessor()

#Load image data and perform image data preprocessing
sdl = SimpleDatasetLoader(preprocessors=[aap,iap])
(data,labels)  = sdl.load(image_paths,verbose=500)
data = data.astype("float") / 255.0


# train test split
(train_x,test_x,train_y,test_y) = train_test_split(data,labels,test_size=0.25,random_state=42)

# convert the labels from integers to vectors
train_y = LabelBinarizer().fit_transform(train_y)
test_y = LabelBinarizer().fit_transform(test_y)
# Out:
# Using TensorFlow backend.
# [INFO] loading images...
# [INFO]: Processed 500/14713
# [INFO]: Processed 1000/14713
# [INFO]: Processed 1500/14713
# [INFO]: Processed 2000/14713
# [INFO]: Processed 2500/14713
# [INFO]: Processed 3000/14713
# [INFO]: Processed 3500/14713
# [INFO]: Processed 4000/14713
# [INFO]: Processed 4500/14713
# [INFO]: Processed 5000/14713
# [INFO]: Processed 5500/14713
# [INFO]: Processed 6000/14713
# [INFO]: Processed 6500/14713
# [INFO]: Processed 7000/14713
# [INFO]: Processed 7500/14713
# [INFO]: Processed 8000/14713
# [INFO]: Processed 8500/14713
# [INFO]: Processed 9000/14713
# [INFO]: Processed 9500/14713
# [INFO]: Processed 10000/14713
# [INFO]: Processed 10500/14713
# [INFO]: Processed 11000/14713
# [INFO]: Processed 11500/14713
# [INFO]: Processed 12000/14713
# [INFO]: Processed 12500/14713
# [INFO]: Processed 13000/14713
# [INFO]: Processed 13500/14713
# [INFO]: Processed 14000/14713
# [INFO]: Processed 14500/14713

# %% [markdown]
# # Load model

# %%
from keras.applications import VGG16
from keras.utils.vis_utils import plot_model
from keras.layers import Input



# Load pretrianed VGG model with FC layers removed
# explicitly deﬁne the input_tensor to be 224×224×3 pixels
base_model = VGG16( weights=None,
                    include_top=False,
                    input_tensor=Input(shape = (input_width,input_height, input_depth)))

plot_save_path = 'diagram-top-removed.png'
# plot_model(base_model, to_file=plot_save_path, show_shapes=True)

# %% [markdown]
# # Custom FC layer

# %%
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense

head_model = base_model.output
head_model = Flatten(name='flatten')(head_model)
head_model = Dense(4096,activation='relu')(head_model)
head_model = Dense(4096,activation='relu')(head_model)
# Add a softmaxc layer
head_model = Dense(len(class_names),activation='softmax')(head_model)

# %% [markdown]
# # Attach custom head to model

# %%
from keras.models import Model


# place the head FC model on top of the base model 
model = Model(inputs=base_model.input, outputs = head_model)

# plot_save_path = 'diagram-head-attached.png'
# plot_model(model, to_file=plot_save_path, show_shapes=True)

# %% [markdown]
# # Compile model

# %%
from keras.optimizers import SGD

# Build the model from the new
print("[INFO] re-compiling model ...")
opt = SGD(lr=0.001, momentum=0.09)

model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])
# Since we only train the new fully connected layer, we do a few iterations
# Out:
# [INFO] re-compiling model ...

# %% [markdown]
# # Checkpoints

# %%
from keras.callbacks import ModelCheckpoint


checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', mode='min', 
save_best_only=True, verbose=1)

callbacks = [checkpoint]

# %%
#load checkpoints if existing

import os

if(os.path.exists(checkpoint_path)):
    model.load_weights(checkpoint_path)

# %% [markdown]
# # Training monitor

# %%
from utils.callbacks.training_monitor import TrainingMonitor
import pathlib
import json
import os

fig_path = "plot"
json_path = "values.json"
values_path = 'values.json'

start_epoch = 127

callbacks.append(TrainingMonitor(fig_path, json_path, start_epoch))

# %% [markdown]
# # Warm up head

# %%
num_of_epochs = 100

model.fit_generator(
    aug.flow(train_x,train_y, batch_size = 32),
             validation_data = (test_x,test_y),
             epochs=num_of_epochs,
             steps_per_epoch = len(train_x) //32,
             verbose = 1,
             callbacks=callbacks)

model.save(model_save_path)
# Out:
# Epoch 1/100
# 344/344 [==============================] - 357s 1s/step - loss: 2.0399 - accuracy: 0.3632 - val_loss: 1.9971 - val_accuracy: 0.3656
#
# Epoch 00001: val_loss improved from inf to 1.99706, saving model to checkpoints-warmup.hdf5
# Epoch 2/100
# 344/344 [==============================] - 334s 970ms/step - loss: 1.9394 - accuracy: 0.3628 - val_loss: 1.8673 - val_accuracy: 0.3656
#
# Epoch 00002: val_loss improved from 1.99706 to 1.86734, saving model to checkpoints-warmup.hdf5
# Epoch 3/100
# 344/344 [==============================] - 334s 970ms/step - loss: 1.8487 - accuracy: 0.3637 - val_loss: 1.8325 - val_accuracy: 0.3656
#
# Epoch 00003: val_loss improved from 1.86734 to 1.83249, saving model to checkpoints-warmup.hdf5
# Epoch 4/100
# 344/344 [==============================] - 333s 968ms/step - loss: 1.8346 - accuracy: 0.3642 - val_loss: 1.8252 - val_accuracy: 0.3656
#
# Epoch 00004: val_loss improved from 1.83249 to 1.82517, saving model to checkpoints-warmup.hdf5
# Epoch 5/100
# 344/344 [==============================] - 333s 967ms/step - loss: 1.8297 - accuracy: 0.3648 - val_loss: 1.8207 - val_accuracy: 0.3656
#
# Epoch 00005: val_loss improved from 1.82517 to 1.82071, saving model to checkpoints-warmup.hdf5
# Epoch 6/100
# 344/344 [==============================] - 334s 971ms/step - loss: 1.8277 - accuracy: 0.3631 - val_loss: 1.8164 - val_accuracy: 0.3656
#
# Epoch 00006: val_loss improved from 1.82071 to 1.81639, saving model to checkpoints-warmup.hdf5
# Epoch 7/100
# 344/344 [==============================] - 334s 972ms/step - loss: 1.8240 - accuracy: 0.3626 - val_loss: 1.8078 - val_accuracy: 0.3656
#
# Epoch 00007: val_loss improved from 1.81639 to 1.80783, saving model to checkpoints-warmup.hdf5
# Epoch 8/100
# 344/344 [==============================] - 333s 969ms/step - loss: 1.8078 - accuracy: 0.3634 - val_loss: 1.7797 - val_accuracy: 0.3656
#
# Epoch 00008: val_loss improved from 1.80783 to 1.77973, saving model to checkpoints-warmup.hdf5
# Epoch 9/100
# 344/344 [==============================] - 333s 969ms/step - loss: 1.7389 - accuracy: 0.3640 - val_loss: 1.6490 - val_accuracy: 0.3656
#
# Epoch 00009: val_loss improved from 1.77973 to 1.64900, saving model to checkpoints-warmup.hdf5
# Epoch 10/100
# 344/344 [==============================] - 335s 974ms/step - loss: 1.5933 - accuracy: 0.3633 - val_loss: 1.5318 - val_accuracy: 0.3656
#
# Epoch 00010: val_loss improved from 1.64900 to 1.53177, saving model to checkpoints-warmup.hdf5
# Epoch 11/100
# 344/344 [==============================] - 335s 975ms/step - loss: 1.5121 - accuracy: 0.3847 - val_loss: 1.4712 - val_accuracy: 0.4142
#
# Epoch 00011: val_loss improved from 1.53177 to 1.47121, saving model to checkpoints-warmup.hdf5
# Epoch 12/100
# 344/344 [==============================] - 335s 973ms/step - loss: 1.4546 - accuracy: 0.4321 - val_loss: 1.4160 - val_accuracy: 0.4537
#
# Epoch 00012: val_loss improved from 1.47121 to 1.41598, saving model to checkpoints-warmup.hdf5
# Epoch 13/100
# 344/344 [==============================] - 335s 973ms/step - loss: 1.4141 - accuracy: 0.4528 - val_loss: 1.3552 - val_accuracy: 0.4678
#
# Epoch 00013: val_loss improved from 1.41598 to 1.35525, saving model to checkpoints-warmup.hdf5
# Epoch 14/100
# 344/344 [==============================] - 335s 975ms/step - loss: 1.3584 - accuracy: 0.5074 - val_loss: 1.2791 - val_accuracy: 0.5333
#
# Epoch 00014: val_loss improved from 1.35525 to 1.27908, saving model to checkpoints-warmup.hdf5
# Epoch 15/100
# 344/344 [==============================] - 335s 974ms/step - loss: 1.2836 - accuracy: 0.5405 - val_loss: 1.2339 - val_accuracy: 0.5523
#
# Epoch 00015: val_loss improved from 1.27908 to 1.23390, saving model to checkpoints-warmup.hdf5
# Epoch 16/100
# 344/344 [==============================] - 335s 973ms/step - loss: 1.2438 - accuracy: 0.5516 - val_loss: 1.1256 - val_accuracy: 0.5966
#
# Epoch 00016: val_loss improved from 1.23390 to 1.12557, saving model to checkpoints-warmup.hdf5
# Epoch 17/100
# 344/344 [==============================] - 334s 972ms/step - loss: 1.2247 - accuracy: 0.5580 - val_loss: 1.0982 - val_accuracy: 0.6162
#
# Epoch 00017: val_loss improved from 1.12557 to 1.09816, saving model to checkpoints-warmup.hdf5
# Epoch 18/100
# 344/344 [==============================] - 335s 974ms/step - loss: 1.1995 - accuracy: 0.5635 - val_loss: 1.0803 - val_accuracy: 0.6227
#
# Epoch 00018: val_loss improved from 1.09816 to 1.08025, saving model to checkpoints-warmup.hdf5
# Epoch 19/100
# 344/344 [==============================] - 335s 975ms/step - loss: 1.1820 - accuracy: 0.5761 - val_loss: 1.0713 - val_accuracy: 0.6146
#
# Epoch 00019: val_loss improved from 1.08025 to 1.07126, saving model to checkpoints-warmup.hdf5
# Epoch 20/100
# 344/344 [==============================] - 335s 973ms/step - loss: 1.1592 - accuracy: 0.5810 - val_loss: 1.0586 - val_accuracy: 0.6320
#
# Epoch 00020: val_loss improved from 1.07126 to 1.05861, saving model to checkpoints-warmup.hdf5
# Epoch 21/100
# 344/344 [==============================] - 334s 972ms/step - loss: 1.1387 - accuracy: 0.5972 - val_loss: 1.1280 - val_accuracy: 0.5871
#
# Epoch 00021: val_loss did not improve from 1.05861
# Epoch 22/100
# 344/344 [==============================] - 334s 972ms/step - loss: 1.1143 - accuracy: 0.6026 - val_loss: 1.1190 - val_accuracy: 0.5980
#
# Epoch 00022: val_loss did not improve from 1.05861
# Epoch 23/100
# 344/344 [==============================] - 335s 972ms/step - loss: 1.0966 - accuracy: 0.6069 - val_loss: 1.0633 - val_accuracy: 0.6197
#
# Epoch 00023: val_loss did not improve from 1.05861
# Epoch 24/100
# 344/344 [==============================] - 334s 971ms/step - loss: 1.0756 - accuracy: 0.6173 - val_loss: 0.9550 - val_accuracy: 0.6597
#
# Epoch 00024: val_loss improved from 1.05861 to 0.95501, saving model to checkpoints-warmup.hdf5
# Epoch 25/100
# 344/344 [==============================] - 334s 970ms/step - loss: 1.0384 - accuracy: 0.6317 - val_loss: 0.9497 - val_accuracy: 0.6730
#
# Epoch 00025: val_loss improved from 0.95501 to 0.94975, saving model to checkpoints-warmup.hdf5
# Epoch 26/100
# 344/344 [==============================] - 335s 973ms/step - loss: 1.0251 - accuracy: 0.6422 - val_loss: 0.8793 - val_accuracy: 0.6969
#
# Epoch 00026: val_loss improved from 0.94975 to 0.87932, saving model to checkpoints-warmup.hdf5
# Epoch 27/100
# 344/344 [==============================] - 335s 973ms/step - loss: 1.0083 - accuracy: 0.6453 - val_loss: 0.8483 - val_accuracy: 0.7062
#
# Epoch 00027: val_loss improved from 0.87932 to 0.84834, saving model to checkpoints-warmup.hdf5
# Epoch 28/100
# 344/344 [==============================] - 334s 971ms/step - loss: 0.9753 - accuracy: 0.6631 - val_loss: 0.8552 - val_accuracy: 0.7026
#
# Epoch 00028: val_loss did not improve from 0.84834
# Epoch 29/100
# 344/344 [==============================] - 334s 971ms/step - loss: 0.9613 - accuracy: 0.6672 - val_loss: 0.8089 - val_accuracy: 0.7312
#
# Epoch 00029: val_loss improved from 0.84834 to 0.80890, saving model to checkpoints-warmup.hdf5
# Epoch 30/100
# 344/344 [==============================] - 335s 974ms/step - loss: 0.9496 - accuracy: 0.6737 - val_loss: 0.8247 - val_accuracy: 0.7154
#
# Epoch 00030: val_loss did not improve from 0.80890
# Epoch 31/100
# 344/344 [==============================] - 335s 975ms/step - loss: 0.9179 - accuracy: 0.6786 - val_loss: 0.7565 - val_accuracy: 0.7388
#
# Epoch 00031: val_loss improved from 0.80890 to 0.75654, saving model to checkpoints-warmup.hdf5
# Epoch 32/100
# 344/344 [==============================] - 335s 973ms/step - loss: 0.8999 - accuracy: 0.6954 - val_loss: 0.7586 - val_accuracy: 0.7363
#
# Epoch 00032: val_loss did not improve from 0.75654
# Epoch 33/100
# 344/344 [==============================] - 335s 973ms/step - loss: 0.8814 - accuracy: 0.6971 - val_loss: 0.7970 - val_accuracy: 0.7247
#
# Epoch 00033: val_loss did not improve from 0.75654
# Epoch 34/100
# 344/344 [==============================] - 335s 974ms/step - loss: 0.8585 - accuracy: 0.7023 - val_loss: 0.7695 - val_accuracy: 0.7355
#
# Epoch 00034: val_loss did not improve from 0.75654
# Epoch 35/100
# 344/344 [==============================] - 335s 974ms/step - loss: 0.8466 - accuracy: 0.7035 - val_loss: 0.7732 - val_accuracy: 0.7328
#
# Epoch 00035: val_loss did not improve from 0.75654
# Epoch 36/100
# 344/344 [==============================] - 335s 974ms/step - loss: 0.8274 - accuracy: 0.7162 - val_loss: 0.7238 - val_accuracy: 0.7548
#
# Epoch 00036: val_loss improved from 0.75654 to 0.72384, saving model to checkpoints-warmup.hdf5
# Epoch 37/100
# 344/344 [==============================] - 334s 972ms/step - loss: 0.8109 - accuracy: 0.7224 - val_loss: 0.6709 - val_accuracy: 0.7687
#
# Epoch 00037: val_loss improved from 0.72384 to 0.67091, saving model to checkpoints-warmup.hdf5
# Epoch 38/100
# 344/344 [==============================] - 336s 975ms/step - loss: 0.8050 - accuracy: 0.7268 - val_loss: 0.6652 - val_accuracy: 0.7646
#
# Epoch 00038: val_loss improved from 0.67091 to 0.66516, saving model to checkpoints-warmup.hdf5
# Epoch 39/100
# 344/344 [==============================] - 335s 975ms/step - loss: 0.7871 - accuracy: 0.7271 - val_loss: 0.6005 - val_accuracy: 0.8013
#
# Epoch 00039: val_loss improved from 0.66516 to 0.60052, saving model to checkpoints-warmup.hdf5
# Epoch 40/100
# 344/344 [==============================] - 335s 973ms/step - loss: 0.7660 - accuracy: 0.7393 - val_loss: 0.6623 - val_accuracy: 0.7763
#
# Epoch 00040: val_loss did not improve from 0.60052
# Epoch 41/100
# 344/344 [==============================] - 335s 973ms/step - loss: 0.7564 - accuracy: 0.7382 - val_loss: 0.6568 - val_accuracy: 0.7668
#
# Epoch 00041: val_loss did not improve from 0.60052
# Epoch 42/100
# 344/344 [==============================] - 335s 974ms/step - loss: 0.7492 - accuracy: 0.7420 - val_loss: 0.5706 - val_accuracy: 0.8078
#
# Epoch 00042: val_loss improved from 0.60052 to 0.57056, saving model to checkpoints-warmup.hdf5
# Epoch 43/100
# 344/344 [==============================] - 336s 975ms/step - loss: 0.7130 - accuracy: 0.7550 - val_loss: 0.5749 - val_accuracy: 0.8038
#
# Epoch 00043: val_loss did not improve from 0.57056
# Epoch 44/100
# 344/344 [==============================] - 335s 973ms/step - loss: 0.7042 - accuracy: 0.7546 - val_loss: 0.6748 - val_accuracy: 0.7698
#
# Epoch 00044: val_loss did not improve from 0.57056
# Epoch 45/100
# 344/344 [==============================] - 334s 971ms/step - loss: 0.6967 - accuracy: 0.7536 - val_loss: 0.5852 - val_accuracy: 0.8018
#
# Epoch 00045: val_loss did not improve from 0.57056
# Epoch 46/100
# 344/344 [==============================] - 335s 975ms/step - loss: 0.6840 - accuracy: 0.7634 - val_loss: 0.5254 - val_accuracy: 0.8263
#
# Epoch 00046: val_loss improved from 0.57056 to 0.52545, saving model to checkpoints-warmup.hdf5
# Epoch 47/100
# 344/344 [==============================] - 335s 975ms/step - loss: 0.6597 - accuracy: 0.7733 - val_loss: 0.5007 - val_accuracy: 0.8312
#
# Epoch 00047: val_loss improved from 0.52545 to 0.50069, saving model to checkpoints-warmup.hdf5
# Epoch 48/100
# 344/344 [==============================] - 335s 972ms/step - loss: 0.6458 - accuracy: 0.7823 - val_loss: 0.6157 - val_accuracy: 0.7853
#
# Epoch 00048: val_loss did not improve from 0.50069
# Epoch 49/100
# 344/344 [==============================] - 334s 971ms/step - loss: 0.6321 - accuracy: 0.7823 - val_loss: 0.5043 - val_accuracy: 0.8258
#
# Epoch 00049: val_loss did not improve from 0.50069
# Epoch 50/100
# 344/344 [==============================] - 335s 973ms/step - loss: 0.6053 - accuracy: 0.7881 - val_loss: 0.4831 - val_accuracy: 0.8315
#
# Epoch 00050: val_loss improved from 0.50069 to 0.48315, saving model to checkpoints-warmup.hdf5
# Epoch 51/100
# 344/344 [==============================] - 335s 974ms/step - loss: 0.6001 - accuracy: 0.7974 - val_loss: 0.5073 - val_accuracy: 0.8279
#
# Epoch 00051: val_loss did not improve from 0.48315
# Epoch 52/100
# 344/344 [==============================] - 334s 971ms/step - loss: 0.5796 - accuracy: 0.8034 - val_loss: 0.4270 - val_accuracy: 0.8524
#
# Epoch 00052: val_loss improved from 0.48315 to 0.42704, saving model to checkpoints-warmup.hdf5
# Epoch 53/100
# 344/344 [==============================] - 335s 972ms/step - loss: 0.5589 - accuracy: 0.8074 - val_loss: 0.3792 - val_accuracy: 0.8739
#
# Epoch 00053: val_loss improved from 0.42704 to 0.37918, saving model to checkpoints-warmup.hdf5
# Epoch 54/100
# 344/344 [==============================] - 335s 974ms/step - loss: 0.5287 - accuracy: 0.8177 - val_loss: 0.4240 - val_accuracy: 0.8551
#
# Epoch 00054: val_loss did not improve from 0.37918
# Epoch 55/100
# 344/344 [==============================] - 335s 973ms/step - loss: 0.5053 - accuracy: 0.8219 - val_loss: 0.3575 - val_accuracy: 0.8769
#
# Epoch 00055: val_loss improved from 0.37918 to 0.35753, saving model to checkpoints-warmup.hdf5
# Epoch 56/100
# 344/344 [==============================] - 335s 973ms/step - loss: 0.5023 - accuracy: 0.8274 - val_loss: 0.3762 - val_accuracy: 0.8714
#
# Epoch 00056: val_loss did not improve from 0.35753
# Epoch 57/100
# 344/344 [==============================] - 334s 971ms/step - loss: 0.4730 - accuracy: 0.8352 - val_loss: 0.4068 - val_accuracy: 0.8540
#
# Epoch 00057: val_loss did not improve from 0.35753
# Epoch 58/100
# 344/344 [==============================] - 335s 973ms/step - loss: 0.4806 - accuracy: 0.8327 - val_loss: 0.3635 - val_accuracy: 0.8663
#
# Epoch 00058: val_loss did not improve from 0.35753
# Epoch 59/100
# 344/344 [==============================] - 335s 973ms/step - loss: 0.4580 - accuracy: 0.8405 - val_loss: 0.3468 - val_accuracy: 0.8815
#
# Epoch 00059: val_loss improved from 0.35753 to 0.34685, saving model to checkpoints-warmup.hdf5
# Epoch 60/100
# 344/344 [==============================] - 334s 972ms/step - loss: 0.4530 - accuracy: 0.8414 - val_loss: 0.4071 - val_accuracy: 0.8589
#
# Epoch 00060: val_loss did not improve from 0.34685
# Epoch 61/100
# 344/344 [==============================] - 334s 972ms/step - loss: 0.4368 - accuracy: 0.8467 - val_loss: 0.3625 - val_accuracy: 0.8695
#
# Epoch 00061: val_loss did not improve from 0.34685
# Epoch 62/100
# 344/344 [==============================] - 335s 973ms/step - loss: 0.4267 - accuracy: 0.8498 - val_loss: 0.3129 - val_accuracy: 0.8905
#
# Epoch 00062: val_loss improved from 0.34685 to 0.31293, saving model to checkpoints-warmup.hdf5
# Epoch 63/100
# 344/344 [==============================] - 336s 976ms/step - loss: 0.4029 - accuracy: 0.8577 - val_loss: 0.2900 - val_accuracy: 0.8981
#
# Epoch 00063: val_loss improved from 0.31293 to 0.29002, saving model to checkpoints-warmup.hdf5
# Epoch 64/100
# 344/344 [==============================] - 335s 975ms/step - loss: 0.4198 - accuracy: 0.8483 - val_loss: 0.3602 - val_accuracy: 0.8742
#
# Epoch 00064: val_loss did not improve from 0.29002
# Epoch 65/100
# 344/344 [==============================] - 335s 973ms/step - loss: 0.3993 - accuracy: 0.8572 - val_loss: 0.4339 - val_accuracy: 0.8453
#
# Epoch 00065: val_loss did not improve from 0.29002
# Epoch 66/100
# 344/344 [==============================] - 336s 975ms/step - loss: 0.3739 - accuracy: 0.8658 - val_loss: 0.3658 - val_accuracy: 0.8671
#
# Epoch 00066: val_loss did not improve from 0.29002
# Epoch 67/100
# 344/344 [==============================] - 336s 976ms/step - loss: 0.3920 - accuracy: 0.8604 - val_loss: 0.4237 - val_accuracy: 0.8519
#
# Epoch 00067: val_loss did not improve from 0.29002
# Epoch 68/100
# 344/344 [==============================] - 335s 974ms/step - loss: 0.3688 - accuracy: 0.8696 - val_loss: 0.2625 - val_accuracy: 0.9057
#
# Epoch 00068: val_loss improved from 0.29002 to 0.26248, saving model to checkpoints-warmup.hdf5
# Epoch 69/100
# 344/344 [==============================] - 335s 974ms/step - loss: 0.3553 - accuracy: 0.8732 - val_loss: 0.2943 - val_accuracy: 0.8951
#
# Epoch 00069: val_loss did not improve from 0.26248
# Epoch 70/100
# 133/344 [==========>...................] - ETA: 3:05 - loss: 0.3527 - accuracy: 0.8722

# %% [markdown]
# # Evaluate with 20% test set from same dataset

# %%
from sklearn.metrics import classification_report

print("[INFO] evaluating after initialization...")
predictions = model.predict(test_x,batch_size=32)
print(classification_report(test_y.argmax(axis =1),
                            predictions.argmax(axis =1),target_names=class_names))
