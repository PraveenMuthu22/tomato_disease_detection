# %% [markdown]
# # Arguments

# %%
num_of_epochs = 25
batch_size = 32
dataset_path_plantvillage = '../datasets/plantvillage'
dataset_path_self = '../datasets/self'
dataset_path_validation = '../datasets/validation'

dataset_paths = [dataset_path_plantvillage, dataset_path_self, dataset_path_validation]

model_save_path = 'model-warmup.h5'

checkpoint_path = 'checkpoints-warmup.hdf5'

input_width = 224
input_height = 224
input_depth = 3

# %% [markdown]
# # Print class names

# %%
# Get classes
import os
import re

class_names = []
class_paths_plant_village = []
class_paths_plant_self = []
class_paths_plant_validation = []

for path in dataset_paths:
    classes = os.listdir(path)
    for i in classes:
        if(re.search('___', i)):
            if(i not in class_names):
                class_names.append(i)
            if(re.search('plantvillage', path)):
                class_paths_plant_village.append(path + '/' + i)
            elif(re.search('self', path)):
                class_paths_plant_self.append(path + '/' + i)
            else:
                class_paths_plant_validation.append(path + '/' + i)

print(class_names)   
print()
print('PlantVillage')
print(class_paths_plant_village) 
print(len(class_paths_plant_village))
print()
print('Self')
print(class_paths_plant_self) 
print(len(class_paths_plant_self))
print()
print('Validation')
print(class_paths_plant_validation) 
print(len(class_paths_plant_validation))
# Out:
# ['___Yellow_Leaf_Curl_Virus', '___Late_blight', '___Early_blight', '___Two-spotted_spider_mite', '___Septoria_leaf_spot', '___Bacterial_spot', '___healthy', '___Target_Spot', '___Mosaic_Virus', '___Leaf_Mold', '___Leaf_miner', '___Appids']
#
# PlantVillage
# ['../datasets/plantvillage/___Yellow_Leaf_Curl_Virus', '../datasets/plantvillage/___Late_blight', '../datasets/plantvillage/___Early_blight', '../datasets/plantvillage/___Two-spotted_spider_mite', '../datasets/plantvillage/___Septoria_leaf_spot', '../datasets/plantvillage/___Bacterial_spot', '../datasets/plantvillage/___healthy', '../datasets/plantvillage/___Target_Spot', '../datasets/plantvillage/___Mosaic_Virus', '../datasets/plantvillage/___Leaf_Mold']
# 10
#
# Self
# ['../datasets/self/___Leaf_miner', '../datasets/self/___Early_blight', '../datasets/self/___Appids']
# 3
#
# Validation
# ['../datasets/validation/___Leaf_miner', '../datasets/validation/___Yellow_Leaf_Curl_Virus', '../datasets/validation/___Late_blight', '../datasets/validation/___Early_blight', '../datasets/validation/___Bacterial_spot', '../datasets/validation/___healthy', '../datasets/validation/___Target_Spot', '../datasets/validation/___Mosaic_Virus', '../datasets/validation/___Leaf_Mold']
# 9

# %% [markdown]
# # Select training classes
#
# early blight in plantVillage dataset replaced by self one

# %%
class_paths_training = ['../datasets/plantvillage/___Late_blight', '../datasets/plantvillage/___Target_Spot', '../datasets/plantvillage/___healthy', '../datasets/plantvillage/___Mosaic_Virus', '../datasets/plantvillage/___Yellow_Leaf_Curl_Virus', '../datasets/plantvillage/___Leaf_Mold', '../datasets/plantvillage/___Bacterial_spot', '../datasets/self/___Early_blight', '../datasets/self/___Appids', '../datasets/self/___Leaf_miner']

# %% [markdown]
# # Load dataset

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.preprocessing.image   import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.layers import Input
from keras.models import Model
from keras .applications import VGG16
from keras.optimizers import SGD
from keras.models import Model
from imutils import paths
import numpy as np
import os

import sys
sys.path.append('..')

from utils.preprocessors.resize_image_preprocessor import resizeImagePreprocessor
from utils.preprocessors.img_to_array_preprocessor import ImgToArrayPreprocessor
from utils.io.simple_dataset_loader import SimpleDatasetLoader

# construct the image generator for data augmentation
aug = ImageDataGenerator(   rotation_range=30,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            shear_range=0.2,
                            zoom_range=0.2,
                            horizontal_flip=True,
                            fill_mode='nearest')

# Load image paths
image_paths = []
print("[INFO] loading images...")
for path in class_paths_training:
    image_paths.extend(list(paths.list_images(path)))
    
# Get unique classnames

class_names = [pt.split(os.path.sep)[-2] for pt in image_paths]
class_names = [str(x) for x in np.unique(class_names)]

# Initial image preprocessing
aap = resizeImagePreprocessor(input_width, input_height)
iap= ImgToArrayPreprocessor()

#Load image data and perform image data preprocessing
sdl = SimpleDatasetLoader(preprocessors=[aap,iap])
(data,labels)  = sdl.load(image_paths,verbose=500)
data = data.astype("float") / 255.0


# train test split
(train_x,test_x,train_y,test_y) = train_test_split(data,labels,test_size=0.25,random_state=42)

# convert the labels from integers to vectors
train_y = LabelBinarizer().fit_transform(train_y)
test_y = LabelBinarizer().fit_transform(test_y)
# Out:
# Using TensorFlow backend.
# [INFO] loading images...
# [INFO]: Processed 500/18087
# [INFO]: Processed 1000/18087
# [INFO]: Processed 1500/18087
# [INFO]: Processed 2000/18087
# [INFO]: Processed 2500/18087
# [INFO]: Processed 3000/18087
# [INFO]: Processed 3500/18087
# [INFO]: Processed 4000/18087
# [INFO]: Processed 4500/18087
# [INFO]: Processed 5000/18087
# [INFO]: Processed 5500/18087
# [INFO]: Processed 6000/18087
# [INFO]: Processed 6500/18087
# [INFO]: Processed 7000/18087
# [INFO]: Processed 7500/18087
# [INFO]: Processed 8000/18087
# [INFO]: Processed 8500/18087
# [INFO]: Processed 9000/18087
# [INFO]: Processed 9500/18087
# [INFO]: Processed 10000/18087
# [INFO]: Processed 10500/18087
# [INFO]: Processed 11000/18087
# [INFO]: Processed 11500/18087
# [INFO]: Processed 12000/18087
# [INFO]: Processed 12500/18087
# [INFO]: Processed 13000/18087
# [INFO]: Processed 13500/18087
# [INFO]: Processed 14000/18087
# [INFO]: Processed 14500/18087
# [INFO]: Processed 15000/18087
# [INFO]: Processed 15500/18087
# [INFO]: Processed 16000/18087
# [INFO]: Processed 16500/18087
# [INFO]: Processed 17000/18087
# [INFO]: Processed 17500/18087
# [INFO]: Processed 18000/18087

# %% [markdown]
# # Load model

# %%
from keras.applications import VGG16
from keras.utils.vis_utils import plot_model
from keras.layers import Input



# Load pretrianed VGG model with FC layers removed
# explicitly deﬁne the input_tensor to be 224×224×3 pixels
base_model = VGG16(weights='imagenet',include_top=False,
                  input_tensor=Input(shape = (input_width,input_height, input_depth)))

# plot_save_path = 'diagram-base-vgg16.png'
# plot_model(base_model, to_file=model_diagram_path, show_shapes=True)

# %% [markdown]
# # Custom FC layer

# %%
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense

head_model = base_model.output
head_model = Flatten(name='flatten')(head_model)
head_model = Dense(256,activation='relu')(head_model)
head_model = Dropout(0.5)(head_model)
# Add a softmaxc layer
head_model = Dense(len(class_names),activation='softmax')(head_model)

# plot_save_path = 'custom-head.png'
# plot_model(head_model, to_file=model_diagram_path, show_shapes=True)

# %% [markdown]
# # Attach custom head to model

# %%
from keras.models import Model


# place the head FC model on top of the base model 
model = Model(inputs=base_model.input, outputs = head_model)

# freeze weights in base model
for layer in base_model.layers:
    layer.trainable = False

# plot_save_path = 'diagram-vgg16-head-attached.png'
# plot_model(model, to_file=model_diagram_path, show_shapes=True)

# %% [markdown]
# # Freeze base model

# %%
# traverse all layers and freeze the weight of the corresponding layer
for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# # Compile model

# %%
from keras.optimizers import SGD

# Build the model from the new
print("[INFO] re-compiling model ...")
opt = SGD(lr=0.001, momentum=0.09)

model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])
# Since we only train the new fully connected layer, we do a few iterations
# Out:
# [INFO] re-compiling model ...

# %% [markdown]
# # Checkpoints

# %%
from keras.callbacks import ModelCheckpoint


checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', mode='min', 
save_best_only=True, verbose=1)

callbacks = [checkpoint]

# %%
#load checkpoints if existing

import os

epochs_done = 0
num_of_epochs = 10

if(os.path.exists(checkpoint_path)):
    model.load_weights(checkpoint_path)
    num_of_epochs = num_of_epochs - epochs_done

# %% [markdown]
# # Training monitor

# %%
from utils.callbacks.training_monitor import TrainingMonitor
import pathlib
import json
import os

fig_path = "plot"
json_path = "values.json"
values_path = 'values.json'
start_epoch = 0

last_epoch = None
last_improved_epoch = None

if(os.path.exists(values_path)):
    with open(values_path) as file_content:
        data = json.load(file_content)
        start_epoch = len(data['val_accuracy']) - (last_epoch - last_improved_epoch)



callbacks.append(TrainingMonitor(fig_path, json_path, start_epoch))

# %% [markdown]
# # Warm up head

# %%
num_of_epochs = 70

model.fit_generator(
    aug.flow(train_x,train_y, batch_size = 32),
             validation_data = (test_x,test_y),
             epochs=num_of_epochs,
             steps_per_epoch = len(train_x) //32,
             verbose = 1,
             callbacks=callbacks)

model.save(model_save_path)
# Out:
# Epoch 1/70
# 423/423 [==============================] - 217s 512ms/step - loss: 1.4899 - accuracy: 0.5006 - val_loss: 0.9771 - val_accuracy: 0.6811
#
# Epoch 00001: val_loss improved from inf to 0.97708, saving model to checkpoints-warmup.hdf5
# Epoch 2/70
# 423/423 [==============================] - 207s 488ms/step - loss: 1.0215 - accuracy: 0.6565 - val_loss: 0.7541 - val_accuracy: 0.7437
#
# Epoch 00002: val_loss improved from 0.97708 to 0.75408, saving model to checkpoints-warmup.hdf5
# Epoch 3/70
# 423/423 [==============================] - 203s 479ms/step - loss: 0.8549 - accuracy: 0.7112 - val_loss: 0.6225 - val_accuracy: 0.7977
#
# Epoch 00003: val_loss improved from 0.75408 to 0.62251, saving model to checkpoints-warmup.hdf5
# Epoch 4/70
# 423/423 [==============================] - 202s 478ms/step - loss: 0.7499 - accuracy: 0.7457 - val_loss: 0.5363 - val_accuracy: 0.8344
#
# Epoch 00004: val_loss improved from 0.62251 to 0.53631, saving model to checkpoints-warmup.hdf5
# Epoch 5/70
# 423/423 [==============================] - 202s 478ms/step - loss: 0.6740 - accuracy: 0.7729 - val_loss: 0.4760 - val_accuracy: 0.8439
#
# Epoch 00005: val_loss improved from 0.53631 to 0.47603, saving model to checkpoints-warmup.hdf5
# Epoch 6/70
# 423/423 [==============================] - 202s 478ms/step - loss: 0.6264 - accuracy: 0.7924 - val_loss: 0.4435 - val_accuracy: 0.8569
#
# Epoch 00006: val_loss improved from 0.47603 to 0.44347, saving model to checkpoints-warmup.hdf5
# Epoch 7/70
# 423/423 [==============================] - 201s 476ms/step - loss: 0.5891 - accuracy: 0.8043 - val_loss: 0.4099 - val_accuracy: 0.8715
#
# Epoch 00007: val_loss improved from 0.44347 to 0.40985, saving model to checkpoints-warmup.hdf5
# Epoch 8/70
# 423/423 [==============================] - 201s 474ms/step - loss: 0.5506 - accuracy: 0.8186 - val_loss: 0.3963 - val_accuracy: 0.8686
#
# Epoch 00008: val_loss improved from 0.40985 to 0.39634, saving model to checkpoints-warmup.hdf5
# Epoch 9/70
# 423/423 [==============================] - 200s 474ms/step - loss: 0.5226 - accuracy: 0.8245 - val_loss: 0.3577 - val_accuracy: 0.8850
#
# Epoch 00009: val_loss improved from 0.39634 to 0.35771, saving model to checkpoints-warmup.hdf5
# Epoch 10/70
# 423/423 [==============================] - 200s 472ms/step - loss: 0.4985 - accuracy: 0.8334 - val_loss: 0.3405 - val_accuracy: 0.8883
#
# Epoch 00010: val_loss improved from 0.35771 to 0.34045, saving model to checkpoints-warmup.hdf5
# Epoch 11/70
# 423/423 [==============================] - 200s 473ms/step - loss: 0.4831 - accuracy: 0.8419 - val_loss: 0.3396 - val_accuracy: 0.8901
#
# Epoch 00011: val_loss improved from 0.34045 to 0.33957, saving model to checkpoints-warmup.hdf5
# Epoch 12/70
# 423/423 [==============================] - 208s 492ms/step - loss: 0.4595 - accuracy: 0.8496 - val_loss: 0.3163 - val_accuracy: 0.9023
#
# Epoch 00012: val_loss improved from 0.33957 to 0.31633, saving model to checkpoints-warmup.hdf5
# Epoch 13/70
# 423/423 [==============================] - 210s 497ms/step - loss: 0.4504 - accuracy: 0.8534 - val_loss: 0.2993 - val_accuracy: 0.9104
#
# Epoch 00013: val_loss improved from 0.31633 to 0.29935, saving model to checkpoints-warmup.hdf5
# Epoch 14/70
# 423/423 [==============================] - 208s 491ms/step - loss: 0.4368 - accuracy: 0.8538 - val_loss: 0.2791 - val_accuracy: 0.9138
#
# Epoch 00014: val_loss improved from 0.29935 to 0.27907, saving model to checkpoints-warmup.hdf5
# Epoch 15/70
# 423/423 [==============================] - 211s 498ms/step - loss: 0.4167 - accuracy: 0.8628 - val_loss: 0.2796 - val_accuracy: 0.9155
#
# Epoch 00015: val_loss did not improve from 0.27907
# Epoch 16/70
# 423/423 [==============================] - 202s 477ms/step - loss: 0.4028 - accuracy: 0.8675 - val_loss: 0.2752 - val_accuracy: 0.9104
#
# Epoch 00016: val_loss improved from 0.27907 to 0.27522, saving model to checkpoints-warmup.hdf5
# Epoch 17/70
# 423/423 [==============================] - 200s 474ms/step - loss: 0.3906 - accuracy: 0.8715 - val_loss: 0.2561 - val_accuracy: 0.9215
#
# Epoch 00017: val_loss improved from 0.27522 to 0.25607, saving model to checkpoints-warmup.hdf5
# Epoch 18/70
# 423/423 [==============================] - 203s 481ms/step - loss: 0.3867 - accuracy: 0.8714 - val_loss: 0.2509 - val_accuracy: 0.9261
#
# Epoch 00018: val_loss improved from 0.25607 to 0.25093, saving model to checkpoints-warmup.hdf5
# Epoch 19/70
# 423/423 [==============================] - 200s 472ms/step - loss: 0.3764 - accuracy: 0.8759 - val_loss: 0.2500 - val_accuracy: 0.9208
#
# Epoch 00019: val_loss improved from 0.25093 to 0.24999, saving model to checkpoints-warmup.hdf5
# Epoch 20/70
# 423/423 [==============================] - 200s 472ms/step - loss: 0.3571 - accuracy: 0.8820 - val_loss: 0.2366 - val_accuracy: 0.9248
#
# Epoch 00020: val_loss improved from 0.24999 to 0.23659, saving model to checkpoints-warmup.hdf5
# Epoch 21/70
# 423/423 [==============================] - 198s 468ms/step - loss: 0.3533 - accuracy: 0.8831 - val_loss: 0.2336 - val_accuracy: 0.9248
#
# Epoch 00021: val_loss improved from 0.23659 to 0.23358, saving model to checkpoints-warmup.hdf5
# Epoch 22/70
# 423/423 [==============================] - 200s 473ms/step - loss: 0.3491 - accuracy: 0.8862 - val_loss: 0.2381 - val_accuracy: 0.9202
#
# Epoch 00022: val_loss did not improve from 0.23358
# Epoch 23/70
# 423/423 [==============================] - 197s 467ms/step - loss: 0.3408 - accuracy: 0.8877 - val_loss: 0.2119 - val_accuracy: 0.9339
#
# Epoch 00023: val_loss improved from 0.23358 to 0.21194, saving model to checkpoints-warmup.hdf5
# Epoch 24/70
# 423/423 [==============================] - 196s 463ms/step - loss: 0.3357 - accuracy: 0.8894 - val_loss: 0.2115 - val_accuracy: 0.9339
#
# Epoch 00024: val_loss improved from 0.21194 to 0.21153, saving model to checkpoints-warmup.hdf5
# Epoch 25/70
# 423/423 [==============================] - 197s 466ms/step - loss: 0.3257 - accuracy: 0.8934 - val_loss: 0.2301 - val_accuracy: 0.9186
#
# Epoch 00025: val_loss did not improve from 0.21153
# Epoch 26/70
# 423/423 [==============================] - 196s 464ms/step - loss: 0.3128 - accuracy: 0.8982 - val_loss: 0.2133 - val_accuracy: 0.9301
#
# Epoch 00026: val_loss did not improve from 0.21153
# Epoch 27/70
# 423/423 [==============================] - 197s 465ms/step - loss: 0.3169 - accuracy: 0.8978 - val_loss: 0.2081 - val_accuracy: 0.9306
#
# Epoch 00027: val_loss improved from 0.21153 to 0.20805, saving model to checkpoints-warmup.hdf5
# Epoch 28/70
# 423/423 [==============================] - 200s 472ms/step - loss: 0.3120 - accuracy: 0.8958 - val_loss: 0.1974 - val_accuracy: 0.9374
#
# Epoch 00028: val_loss improved from 0.20805 to 0.19740, saving model to checkpoints-warmup.hdf5
# Epoch 29/70
# 423/423 [==============================] - 197s 466ms/step - loss: 0.3026 - accuracy: 0.9000 - val_loss: 0.2006 - val_accuracy: 0.9365
#
# Epoch 00029: val_loss did not improve from 0.19740
# Epoch 30/70
# 423/423 [==============================] - 198s 468ms/step - loss: 0.2946 - accuracy: 0.9027 - val_loss: 0.2013 - val_accuracy: 0.9332
#
# Epoch 00030: val_loss did not improve from 0.19740
# Epoch 31/70
# 423/423 [==============================] - 200s 472ms/step - loss: 0.2893 - accuracy: 0.9050 - val_loss: 0.1953 - val_accuracy: 0.9374
#
# Epoch 00031: val_loss improved from 0.19740 to 0.19533, saving model to checkpoints-warmup.hdf5
# Epoch 32/70
# 423/423 [==============================] - 198s 469ms/step - loss: 0.2923 - accuracy: 0.9042 - val_loss: 0.1888 - val_accuracy: 0.9445
#
# Epoch 00032: val_loss improved from 0.19533 to 0.18876, saving model to checkpoints-warmup.hdf5
# Epoch 33/70
# 423/423 [==============================] - 199s 471ms/step - loss: 0.2877 - accuracy: 0.9051 - val_loss: 0.1932 - val_accuracy: 0.9383
#
# Epoch 00033: val_loss did not improve from 0.18876
# Epoch 34/70
# 423/423 [==============================] - 196s 464ms/step - loss: 0.2833 - accuracy: 0.9044 - val_loss: 0.1947 - val_accuracy: 0.9363
#
# Epoch 00034: val_loss did not improve from 0.18876
# Epoch 35/70
# 423/423 [==============================] - 203s 480ms/step - loss: 0.2718 - accuracy: 0.9114 - val_loss: 0.1804 - val_accuracy: 0.9410
#
# Epoch 00035: val_loss improved from 0.18876 to 0.18037, saving model to checkpoints-warmup.hdf5
# Epoch 36/70
# 423/423 [==============================] - 200s 473ms/step - loss: 0.2719 - accuracy: 0.9117 - val_loss: 0.1802 - val_accuracy: 0.9412
#
# Epoch 00036: val_loss improved from 0.18037 to 0.18015, saving model to checkpoints-warmup.hdf5
# Epoch 37/70
# 423/423 [==============================] - 200s 473ms/step - loss: 0.2706 - accuracy: 0.9103 - val_loss: 0.1780 - val_accuracy: 0.9421
#
# Epoch 00037: val_loss improved from 0.18015 to 0.17796, saving model to checkpoints-warmup.hdf5
# Epoch 38/70
# 423/423 [==============================] - 205s 485ms/step - loss: 0.2653 - accuracy: 0.9142 - val_loss: 0.1718 - val_accuracy: 0.9494
#
# Epoch 00038: val_loss improved from 0.17796 to 0.17177, saving model to checkpoints-warmup.hdf5
# Epoch 39/70
# 423/423 [==============================] - 206s 488ms/step - loss: 0.2632 - accuracy: 0.9119 - val_loss: 0.1744 - val_accuracy: 0.9441
#
# Epoch 00039: val_loss did not improve from 0.17177
# Epoch 40/70
# 423/423 [==============================] - 199s 471ms/step - loss: 0.2628 - accuracy: 0.9147 - val_loss: 0.1756 - val_accuracy: 0.9438
#
# Epoch 00040: val_loss did not improve from 0.17177
# Epoch 41/70
# 423/423 [==============================] - 201s 475ms/step - loss: 0.2614 - accuracy: 0.9125 - val_loss: 0.1853 - val_accuracy: 0.9416
#
# Epoch 00041: val_loss did not improve from 0.17177
# Epoch 42/70
# 423/423 [==============================] - 202s 477ms/step - loss: 0.2567 - accuracy: 0.9155 - val_loss: 0.1708 - val_accuracy: 0.9465
#
# Epoch 00042: val_loss improved from 0.17177 to 0.17075, saving model to checkpoints-warmup.hdf5
# Epoch 43/70
# 423/423 [==============================] - 200s 472ms/step - loss: 0.2505 - accuracy: 0.9153 - val_loss: 0.1713 - val_accuracy: 0.9463
#
# Epoch 00043: val_loss did not improve from 0.17075
# Epoch 44/70
# 423/423 [==============================] - 199s 471ms/step - loss: 0.2496 - accuracy: 0.9177 - val_loss: 0.1696 - val_accuracy: 0.9447
#
# Epoch 00044: val_loss improved from 0.17075 to 0.16965, saving model to checkpoints-warmup.hdf5
# Epoch 45/70
# 423/423 [==============================] - 197s 466ms/step - loss: 0.2508 - accuracy: 0.9175 - val_loss: 0.1619 - val_accuracy: 0.9502
#
# Epoch 00045: val_loss improved from 0.16965 to 0.16192, saving model to checkpoints-warmup.hdf5
# Epoch 46/70
# 423/423 [==============================] - 197s 466ms/step - loss: 0.2485 - accuracy: 0.9175 - val_loss: 0.1753 - val_accuracy: 0.9421
#
# Epoch 00046: val_loss did not improve from 0.16192
# Epoch 47/70
# 423/423 [==============================] - 196s 463ms/step - loss: 0.2449 - accuracy: 0.9196 - val_loss: 0.1565 - val_accuracy: 0.9513
#
# Epoch 00047: val_loss improved from 0.16192 to 0.15646, saving model to checkpoints-warmup.hdf5
# Epoch 48/70
# 423/423 [==============================] - 201s 476ms/step - loss: 0.2457 - accuracy: 0.9206 - val_loss: 0.1514 - val_accuracy: 0.9542
#
# Epoch 00048: val_loss improved from 0.15646 to 0.15141, saving model to checkpoints-warmup.hdf5
# Epoch 49/70
# 423/423 [==============================] - 202s 478ms/step - loss: 0.2405 - accuracy: 0.9200 - val_loss: 0.1607 - val_accuracy: 0.9478
#
# Epoch 00049: val_loss did not improve from 0.15141
# Epoch 50/70
# 423/423 [==============================] - 201s 475ms/step - loss: 0.2374 - accuracy: 0.9232 - val_loss: 0.1507 - val_accuracy: 0.9502
#
# Epoch 00050: val_loss improved from 0.15141 to 0.15071, saving model to checkpoints-warmup.hdf5
# Epoch 51/70
# 423/423 [==============================] - 202s 477ms/step - loss: 0.2299 - accuracy: 0.9241 - val_loss: 0.1468 - val_accuracy: 0.9547
#
# Epoch 00051: val_loss improved from 0.15071 to 0.14680, saving model to checkpoints-warmup.hdf5
# Epoch 52/70
# 423/423 [==============================] - 198s 469ms/step - loss: 0.2368 - accuracy: 0.9194 - val_loss: 0.1494 - val_accuracy: 0.9536
#
# Epoch 00052: val_loss did not improve from 0.14680
# Epoch 53/70
# 423/423 [==============================] - 197s 466ms/step - loss: 0.2303 - accuracy: 0.9236 - val_loss: 0.1504 - val_accuracy: 0.9525
#
# Epoch 00053: val_loss did not improve from 0.14680
# Epoch 54/70
# 423/423 [==============================] - 195s 461ms/step - loss: 0.2270 - accuracy: 0.9255 - val_loss: 0.1460 - val_accuracy: 0.9531
#
# Epoch 00054: val_loss improved from 0.14680 to 0.14599, saving model to checkpoints-warmup.hdf5
# Epoch 55/70
# 423/423 [==============================] - 195s 462ms/step - loss: 0.2195 - accuracy: 0.9256 - val_loss: 0.1526 - val_accuracy: 0.9527
#
# Epoch 00055: val_loss did not improve from 0.14599
# Epoch 56/70
# 423/423 [==============================] - 195s 461ms/step - loss: 0.2224 - accuracy: 0.9248 - val_loss: 0.1522 - val_accuracy: 0.9516
#
# Epoch 00056: val_loss did not improve from 0.14599
# Epoch 57/70
# 423/423 [==============================] - 196s 464ms/step - loss: 0.2197 - accuracy: 0.9273 - val_loss: 0.1470 - val_accuracy: 0.9518
#
# Epoch 00057: val_loss did not improve from 0.14599
# Epoch 58/70
# 423/423 [==============================] - 195s 462ms/step - loss: 0.2164 - accuracy: 0.9284 - val_loss: 0.1589 - val_accuracy: 0.9513
#
# Epoch 00058: val_loss did not improve from 0.14599
# Epoch 59/70
# 423/423 [==============================] - 196s 464ms/step - loss: 0.2256 - accuracy: 0.9260 - val_loss: 0.1413 - val_accuracy: 0.9549
#
# Epoch 00059: val_loss improved from 0.14599 to 0.14125, saving model to checkpoints-warmup.hdf5
# Epoch 60/70
# 423/423 [==============================] - 196s 463ms/step - loss: 0.2175 - accuracy: 0.9276 - val_loss: 0.1420 - val_accuracy: 0.9536
#
# Epoch 00060: val_loss did not improve from 0.14125
# Epoch 61/70
# 423/423 [==============================] - 195s 461ms/step - loss: 0.2157 - accuracy: 0.9282 - val_loss: 0.1389 - val_accuracy: 0.9542
#
# Epoch 00061: val_loss improved from 0.14125 to 0.13891, saving model to checkpoints-warmup.hdf5
# Epoch 62/70
# 423/423 [==============================] - 195s 462ms/step - loss: 0.2150 - accuracy: 0.9282 - val_loss: 0.1347 - val_accuracy: 0.9573
#
# Epoch 00062: val_loss improved from 0.13891 to 0.13472, saving model to checkpoints-warmup.hdf5
# Epoch 63/70
# 423/423 [==============================] - 197s 465ms/step - loss: 0.2068 - accuracy: 0.9315 - val_loss: 0.1489 - val_accuracy: 0.9505
#
# Epoch 00063: val_loss did not improve from 0.13472
# Epoch 64/70
# 423/423 [==============================] - 195s 462ms/step - loss: 0.2023 - accuracy: 0.9352 - val_loss: 0.1365 - val_accuracy: 0.9549
#
# Epoch 00064: val_loss did not improve from 0.13472
# Epoch 65/70
# 423/423 [==============================] - 196s 462ms/step - loss: 0.2107 - accuracy: 0.9295 - val_loss: 0.1371 - val_accuracy: 0.9586
#
# Epoch 00065: val_loss did not improve from 0.13472
# Epoch 66/70
# 423/423 [==============================] - 195s 461ms/step - loss: 0.2062 - accuracy: 0.9320 - val_loss: 0.1363 - val_accuracy: 0.9558
#
# Epoch 00066: val_loss did not improve from 0.13472
# Epoch 67/70
# 423/423 [==============================] - 195s 461ms/step - loss: 0.2123 - accuracy: 0.9311 - val_loss: 0.1336 - val_accuracy: 0.9556
#
# Epoch 00067: val_loss improved from 0.13472 to 0.13363, saving model to checkpoints-warmup.hdf5
# Epoch 68/70
# 423/423 [==============================] - 195s 462ms/step - loss: 0.2049 - accuracy: 0.9321 - val_loss: 0.1348 - val_accuracy: 0.9589
#
# Epoch 00068: val_loss did not improve from 0.13363
# Epoch 69/70
# 423/423 [==============================] - 196s 464ms/step - loss: 0.2027 - accuracy: 0.9351 - val_loss: 0.1338 - val_accuracy: 0.9573
#
# Epoch 00069: val_loss did not improve from 0.13363
# Epoch 70/70
# 423/423 [==============================] - 196s 463ms/step - loss: 0.1984 - accuracy: 0.9354 - val_loss: 0.1396 - val_accuracy: 0.9549
#
# Epoch 00070: val_loss did not improve from 0.13363

# %% [markdown]
# # Evaluate with 20% test set from same dataset

# %%
from sklearn.metrics import classification_report

print("[INFO] evaluating after initialization...")
predictions = model.predict(test_x,batch_size=32)
print(classification_report(test_y.argmax(axis =1),
                            predictions.argmax(axis =1),target_names=class_names))
# Out:
# [INFO] evaluating after initialization...
#                            precision    recall  f1-score   support
#
#                 ___Appids       0.97      0.95      0.96       259
#         ___Bacterial_spot       0.94      0.98      0.96       531
#           ___Early_blight       0.99      0.86      0.92       373
#            ___Late_blight       0.97      0.92      0.95       459
#              ___Leaf_Mold       0.95      0.84      0.89       242
#             ___Leaf_miner       0.88      0.98      0.93       451
#           ___Mosaic_Virus       0.93      1.00      0.96       101
#            ___Target_Spot       0.89      0.96      0.92       356
# ___Yellow_Leaf_Curl_Virus       0.99      0.99      0.99      1357
#                ___healthy       0.97      0.98      0.98       393
#
#               avg / total       0.96      0.95      0.95      4522
