# %% [markdown]
# # Parameters

# %%
num_of_epochs = 100
batch_size = 32
dataset_name = 'plantVillage-tomato-mohanty'
dataset_path = '../datasets/' + dataset_name
model_diagram_path = 'alexnet_model_diagram.png'
model_save_path = 'plantVillage-alexnet-from-scratch.h5'
plot_save_path = 'plot-plantVillage-alexnet-from-scratch.png'

# %% [markdown]
# # Load dataset

# %%
import sys, os
sys.path.append('..')
import numpy as np
from imutils import paths



from utils.preprocessors.resize_image_preprocessor import resizeImagePreprocessor
from utils.preprocessors.img_to_array_preprocessor import ImgToArrayPreprocessor
from utils.io.simple_dataset_loader import SimpleDatasetLoader

# Get the list of image names
image_paths = list(paths.list_images(dataset_path))

print(len(image_paths), 'images loaded')

# Get unique class_names
class_names = [pt.split(os.path.sep)[-2] for pt in image_paths]
class_names = [str(x) for x in np.unique(class_names)]
print(class_names)


# Preprocessors
aap = resizeImagePreprocessor(227, 227)
itap = ImgToArrayPreprocessor()

# Add preprocessors to DataSetLoader class
sdl = SimpleDatasetLoader(preprocessors=[aap, itap])

(data, labels) = sdl.load(image_paths, verbose=500)
data = data.astype('float') / 255.0
# Out:
# Using TensorFlow backend.
# 18160 images loaded
# ['Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']
# [INFO]: Processed 500/18160
# [INFO]: Processed 1000/18160
# [INFO]: Processed 1500/18160
# [INFO]: Processed 2000/18160
# [INFO]: Processed 2500/18160
# [INFO]: Processed 3000/18160
# [INFO]: Processed 3500/18160
# [INFO]: Processed 4000/18160
# [INFO]: Processed 4500/18160
# [INFO]: Processed 5000/18160
# [INFO]: Processed 5500/18160
# [INFO]: Processed 6000/18160
# [INFO]: Processed 6500/18160
# [INFO]: Processed 7000/18160
# [INFO]: Processed 7500/18160
# [INFO]: Processed 8000/18160
# [INFO]: Processed 8500/18160
# [INFO]: Processed 9000/18160
# [INFO]: Processed 9500/18160
# [INFO]: Processed 10000/18160
# [INFO]: Processed 10500/18160
# [INFO]: Processed 11000/18160
# [INFO]: Processed 11500/18160
# [INFO]: Processed 12000/18160
# [INFO]: Processed 12500/18160
# [INFO]: Processed 13000/18160
# [INFO]: Processed 13500/18160
# [INFO]: Processed 14000/18160
# [INFO]: Processed 14500/18160
# [INFO]: Processed 15000/18160
# [INFO]: Processed 15500/18160
# [INFO]: Processed 16000/18160
# [INFO]: Processed 16500/18160
# [INFO]: Processed 17000/18160
# [INFO]: Processed 17500/18160
# [INFO]: Processed 18000/18160

# %% [markdown]
# # Encode labels and split dataset

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

# Split data into training (75%) and testing (25%) data
(train_x, test_x, train_y, test_y) = train_test_split(data, labels,
test_size=0.25, random_state=0)

# Convert the labels from integers to vectors
lb = LabelBinarizer()
train_y = lb.fit_transform(train_y)
test_y = lb.transform(test_y)

# %% [markdown]
# # Initialize model

# %%
import os, sys
# import pydot_ng as pydot
# pydot.find_graphviz()
# os.environ.get('PATH', '')

# remove these
# sys.path.append('..')
# class_names = ['one', 'two', 'three', 'four']
# remove these

from utils.models.alexnet import alexnet
from keras.utils.vis_utils import plot_model
from keras.optimizers import SGD

model = alexnet(len(class_names))
model.summary()

# plot_model(model, to_file=model_diagram_path, show_shapes=True)

# copile model
opt = SGD(lr=0.05)
model.compile(loss="categorical_crossentropy", optimizer=opt,
              metrics=["accuracy"])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 55, 55, 96)        34944
# _________________________________________________________________
# activation_1 (Activation)    (None, 55, 55, 96)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 27, 27, 96)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 17, 17, 256)       2973952
# _________________________________________________________________
# activation_2 (Activation)    (None, 17, 17, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 384)         885120
# _________________________________________________________________
# activation_3 (Activation)    (None, 6, 6, 384)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 384)         1327488
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 4, 384)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 256)         884992
# _________________________________________________________________
# activation_5 (Activation)    (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              1052672
# _________________________________________________________________
# activation_6 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_7 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# activation_8 (Activation)    (None, 1000)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                10010
# _________________________________________________________________
# activation_9 (Activation)    (None, 10)                0
# =================================================================
# Total params: 28,047,490
# Trainable params: 28,047,490
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Fit model

# %%
# train the network
print("[INFO] training network...")
H = model.fit(train_x, train_y, validation_data=(test_x, test_y),
              batch_size=batch_size, epochs=num_of_epochs, verbose=1)

model.save(model_save_path)
# Out:
# [INFO] training network...
# Train on 13620 samples, validate on 4540 samples
# Epoch 1/100
# 13620/13620 [==============================] - 53s 4ms/step - loss: 2.0865 - accuracy: 0.2935 - val_loss: 1.7608 - val_accuracy: 0.3711
# Epoch 2/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.7820 - accuracy: 0.3783 - val_loss: 1.5245 - val_accuracy: 0.4815
# Epoch 3/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.4483 - accuracy: 0.5035 - val_loss: 1.2305 - val_accuracy: 0.5784
# Epoch 4/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.1912 - accuracy: 0.5945 - val_loss: 0.9624 - val_accuracy: 0.6716
# Epoch 5/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.9807 - accuracy: 0.6700 - val_loss: 2.6415 - val_accuracy: 0.3626
# Epoch 6/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.8708 - accuracy: 0.7099 - val_loss: 1.1610 - val_accuracy: 0.6104
# Epoch 7/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.6979 - accuracy: 0.7653 - val_loss: 0.5811 - val_accuracy: 0.7954
# Epoch 8/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.5849 - accuracy: 0.8037 - val_loss: 0.4458 - val_accuracy: 0.8465
# Epoch 9/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.4631 - accuracy: 0.8454 - val_loss: 0.6580 - val_accuracy: 0.7753
# Epoch 10/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.4138 - accuracy: 0.8605 - val_loss: 0.7046 - val_accuracy: 0.7608
# Epoch 11/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.3585 - accuracy: 0.8787 - val_loss: 0.3622 - val_accuracy: 0.8800
# Epoch 12/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.2797 - accuracy: 0.9068 - val_loss: 0.3755 - val_accuracy: 0.8846
# Epoch 13/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.2497 - accuracy: 0.9147 - val_loss: 0.3950 - val_accuracy: 0.8694
# Epoch 14/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.2108 - accuracy: 0.9308 - val_loss: 0.4379 - val_accuracy: 0.8608
# Epoch 15/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.1595 - accuracy: 0.9490 - val_loss: 0.3170 - val_accuracy: 0.8996
# Epoch 16/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.1498 - accuracy: 0.9529 - val_loss: 0.3489 - val_accuracy: 0.8934
# Epoch 17/100
# 13620/13620 [==============================] - 46s 3ms/step - loss: 0.1301 - accuracy: 0.9597 - val_loss: 0.2819 - val_accuracy: 0.9130
# Epoch 18/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0785 - accuracy: 0.9758 - val_loss: 0.3256 - val_accuracy: 0.9095
# Epoch 19/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0927 - accuracy: 0.9713 - val_loss: 0.3075 - val_accuracy: 0.9086
# Epoch 20/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0643 - accuracy: 0.9810 - val_loss: 0.3599 - val_accuracy: 0.9086
# Epoch 21/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0876 - accuracy: 0.9733 - val_loss: 0.3299 - val_accuracy: 0.9066
# Epoch 22/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0660 - accuracy: 0.9811 - val_loss: 0.3359 - val_accuracy: 0.9031
# Epoch 23/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0720 - accuracy: 0.9797 - val_loss: 0.3012 - val_accuracy: 0.9172
# Epoch 24/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0256 - accuracy: 0.9927 - val_loss: 0.3154 - val_accuracy: 0.9256
# Epoch 25/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0232 - accuracy: 0.9942 - val_loss: 0.7008 - val_accuracy: 0.8407
# Epoch 26/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0568 - accuracy: 0.9828 - val_loss: 0.3967 - val_accuracy: 0.9044
# Epoch 27/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0600 - accuracy: 0.9849 - val_loss: 0.3458 - val_accuracy: 0.9004
# Epoch 28/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0346 - accuracy: 0.9896 - val_loss: 0.3600 - val_accuracy: 0.9161
# Epoch 29/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0212 - accuracy: 0.9943 - val_loss: 0.3099 - val_accuracy: 0.9264
# Epoch 30/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0301 - accuracy: 0.9926 - val_loss: 0.9636 - val_accuracy: 0.8471
# Epoch 31/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0348 - accuracy: 0.9896 - val_loss: 0.2962 - val_accuracy: 0.9335
# Epoch 32/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0842 - accuracy: 0.9802 - val_loss: 0.2628 - val_accuracy: 0.9293
# Epoch 33/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0194 - accuracy: 0.9945 - val_loss: 0.3701 - val_accuracy: 0.9150
# Epoch 34/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0183 - accuracy: 0.9950 - val_loss: 0.7275 - val_accuracy: 0.8555
# Epoch 35/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0247 - accuracy: 0.9927 - val_loss: 0.3467 - val_accuracy: 0.9240
# Epoch 36/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0142 - accuracy: 0.9960 - val_loss: 0.3327 - val_accuracy: 0.9260
# Epoch 37/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.3541 - val_accuracy: 0.9249
# Epoch 38/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0231 - accuracy: 0.9937 - val_loss: 0.3458 - val_accuracy: 0.9231
# Epoch 39/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0274 - accuracy: 0.9921 - val_loss: 0.3596 - val_accuracy: 0.9205
# Epoch 40/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 0.0184 - accuracy: 0.9949 - val_loss: 0.3191 - val_accuracy: 0.9267
# Epoch 41/100
# 13620/13620 [==============================] - 46s 3ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.3095 - val_accuracy: 0.9374
# Epoch 42/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 2.8026e-04 - accuracy: 1.0000 - val_loss: 0.3186 - val_accuracy: 0.9368
# Epoch 43/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.7680e-04 - accuracy: 1.0000 - val_loss: 0.3203 - val_accuracy: 0.9381
# Epoch 44/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.6430e-04 - accuracy: 1.0000 - val_loss: 0.3315 - val_accuracy: 0.9390
# Epoch 45/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.1590e-04 - accuracy: 1.0000 - val_loss: 0.3360 - val_accuracy: 0.9388
# Epoch 46/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 8.1564e-05 - accuracy: 1.0000 - val_loss: 0.3387 - val_accuracy: 0.9396
# Epoch 47/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 7.7701e-05 - accuracy: 1.0000 - val_loss: 0.3411 - val_accuracy: 0.9392
# Epoch 48/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 7.1427e-05 - accuracy: 1.0000 - val_loss: 0.3422 - val_accuracy: 0.9399
# Epoch 49/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 7.2163e-05 - accuracy: 1.0000 - val_loss: 0.3457 - val_accuracy: 0.9392
# Epoch 50/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 4.9897e-05 - accuracy: 1.0000 - val_loss: 0.3484 - val_accuracy: 0.9390
# Epoch 51/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 5.3943e-05 - accuracy: 1.0000 - val_loss: 0.3493 - val_accuracy: 0.9392
# Epoch 52/100
# 13620/13620 [==============================] - 46s 3ms/step - loss: 4.6674e-05 - accuracy: 1.0000 - val_loss: 0.3515 - val_accuracy: 0.9392
# Epoch 53/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 4.8304e-05 - accuracy: 1.0000 - val_loss: 0.3532 - val_accuracy: 0.9396
# Epoch 54/100
# 13620/13620 [==============================] - 46s 3ms/step - loss: 3.5869e-05 - accuracy: 1.0000 - val_loss: 0.3551 - val_accuracy: 0.9390
# Epoch 55/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 3.4484e-05 - accuracy: 1.0000 - val_loss: 0.3569 - val_accuracy: 0.9390
# Epoch 56/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 3.9162e-05 - accuracy: 1.0000 - val_loss: 0.3588 - val_accuracy: 0.9394
# Epoch 57/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 3.3969e-05 - accuracy: 1.0000 - val_loss: 0.3608 - val_accuracy: 0.9390
# Epoch 58/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 2.9230e-05 - accuracy: 1.0000 - val_loss: 0.3622 - val_accuracy: 0.9394
# Epoch 59/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 2.9279e-05 - accuracy: 1.0000 - val_loss: 0.3640 - val_accuracy: 0.9396
# Epoch 60/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 2.6394e-05 - accuracy: 1.0000 - val_loss: 0.3650 - val_accuracy: 0.9390
# Epoch 61/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 2.7745e-05 - accuracy: 1.0000 - val_loss: 0.3670 - val_accuracy: 0.9392
# Epoch 62/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 2.3131e-05 - accuracy: 1.0000 - val_loss: 0.3684 - val_accuracy: 0.9396
# Epoch 63/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 2.7972e-05 - accuracy: 1.0000 - val_loss: 0.3704 - val_accuracy: 0.9390
# Epoch 64/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 2.1037e-05 - accuracy: 1.0000 - val_loss: 0.3719 - val_accuracy: 0.9390
# Epoch 65/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 2.1860e-05 - accuracy: 1.0000 - val_loss: 0.3728 - val_accuracy: 0.9385
# Epoch 66/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 2.6254e-05 - accuracy: 1.0000 - val_loss: 0.3742 - val_accuracy: 0.9392
# Epoch 67/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 2.0036e-05 - accuracy: 1.0000 - val_loss: 0.3753 - val_accuracy: 0.9392
# Epoch 68/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 2.2237e-05 - accuracy: 1.0000 - val_loss: 0.3749 - val_accuracy: 0.9396
# Epoch 69/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 2.0335e-05 - accuracy: 1.0000 - val_loss: 0.3763 - val_accuracy: 0.9401
# Epoch 70/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 2.2765e-05 - accuracy: 1.0000 - val_loss: 0.3775 - val_accuracy: 0.9396
# Epoch 71/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.8564e-05 - accuracy: 1.0000 - val_loss: 0.3785 - val_accuracy: 0.9401
# Epoch 72/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.8196e-05 - accuracy: 1.0000 - val_loss: 0.3795 - val_accuracy: 0.9396
# Epoch 73/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.6653e-05 - accuracy: 1.0000 - val_loss: 0.3808 - val_accuracy: 0.9394
# Epoch 74/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.5354e-05 - accuracy: 1.0000 - val_loss: 0.3820 - val_accuracy: 0.9401
# Epoch 75/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.8126e-05 - accuracy: 1.0000 - val_loss: 0.3824 - val_accuracy: 0.9394
# Epoch 76/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.6416e-05 - accuracy: 1.0000 - val_loss: 0.3834 - val_accuracy: 0.9388
# Epoch 77/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.9404e-05 - accuracy: 1.0000 - val_loss: 0.3823 - val_accuracy: 0.9399
# Epoch 78/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.6720e-05 - accuracy: 1.0000 - val_loss: 0.3827 - val_accuracy: 0.9401
# Epoch 79/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.3448e-05 - accuracy: 1.0000 - val_loss: 0.3837 - val_accuracy: 0.9401
# Epoch 80/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.5784e-05 - accuracy: 1.0000 - val_loss: 0.3847 - val_accuracy: 0.9392
# Epoch 81/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.2193e-05 - accuracy: 1.0000 - val_loss: 0.3855 - val_accuracy: 0.9392
# Epoch 82/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.2504e-05 - accuracy: 1.0000 - val_loss: 0.3865 - val_accuracy: 0.9394
# Epoch 83/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.4810e-05 - accuracy: 1.0000 - val_loss: 0.3875 - val_accuracy: 0.9394
# Epoch 84/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.4527e-05 - accuracy: 1.0000 - val_loss: 0.3881 - val_accuracy: 0.9388
# Epoch 85/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.2196e-05 - accuracy: 1.0000 - val_loss: 0.3890 - val_accuracy: 0.9392
# Epoch 86/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.3960e-05 - accuracy: 1.0000 - val_loss: 0.3901 - val_accuracy: 0.9394
# Epoch 87/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.2171e-05 - accuracy: 1.0000 - val_loss: 0.3908 - val_accuracy: 0.9392
# Epoch 88/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.0276e-05 - accuracy: 1.0000 - val_loss: 0.3918 - val_accuracy: 0.9399
# Epoch 89/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.0065e-05 - accuracy: 1.0000 - val_loss: 0.3924 - val_accuracy: 0.9399
# Epoch 90/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 9.9269e-06 - accuracy: 1.0000 - val_loss: 0.3933 - val_accuracy: 0.9401
# Epoch 91/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.0818e-05 - accuracy: 1.0000 - val_loss: 0.3941 - val_accuracy: 0.9401
# Epoch 92/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.0736e-05 - accuracy: 1.0000 - val_loss: 0.3946 - val_accuracy: 0.9401
# Epoch 93/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.1692e-05 - accuracy: 1.0000 - val_loss: 0.3949 - val_accuracy: 0.9401
# Epoch 94/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.0448e-05 - accuracy: 1.0000 - val_loss: 0.3954 - val_accuracy: 0.9403
# Epoch 95/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.1284e-05 - accuracy: 1.0000 - val_loss: 0.3954 - val_accuracy: 0.9399
# Epoch 96/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 1.1875e-05 - accuracy: 1.0000 - val_loss: 0.3960 - val_accuracy: 0.9390
# Epoch 97/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 8.9654e-06 - accuracy: 1.0000 - val_loss: 0.3966 - val_accuracy: 0.9390
# Epoch 98/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 9.4502e-06 - accuracy: 1.0000 - val_loss: 0.3971 - val_accuracy: 0.9390
# Epoch 99/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 8.5025e-06 - accuracy: 1.0000 - val_loss: 0.3977 - val_accuracy: 0.9392
# Epoch 100/100
# 13620/13620 [==============================] - 45s 3ms/step - loss: 8.9206e-06 - accuracy: 1.0000 - val_loss: 0.3985 - val_accuracy: 0.9394

# %% [markdown]
# # Generate classfication report

# %%
from sklearn.metrics import classification_report


# If one hot encoding is used
predictions = model.predict(test_x, batch_size=batch_size)
print(classification_report(test_y.argmax(axis=1), predictions.argmax(axis=1), target_names=class_names))
# Out:
#                                                precision    recall  f1-score   support
#
#                       Tomato___Bacterial_spot       0.95      0.96      0.95       572
#                         Tomato___Early_blight       0.76      0.72      0.74       239
#                          Tomato___Late_blight       0.91      0.90      0.91       446
#                            Tomato___Leaf_Mold       0.91      0.94      0.93       231
#                   Tomato___Septoria_leaf_spot       0.90      0.92      0.91       425
# Tomato___Spider_mites Two-spotted_spider_mite       0.93      0.94      0.94       401
#                          Tomato___Target_Spot       0.92      0.89      0.90       345
#        Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.99      0.99      0.99      1360
#                  Tomato___Tomato_mosaic_virus       0.95      0.89      0.92       102
#                              Tomato___healthy       0.97      0.99      0.98       419
#
#                                   avg / total       0.94      0.94      0.94      4540

# %% [markdown]
# # Plot model

# %%
print(H.history.keys())

# print('loss')
# print(H.history['loss'])
# print('')

# print('accuracy')
# print(H.history['accuracy'])
# print('')


# print('val_loss')
# print(H.history['val_loss'])
# print('')

# print('val_accuracy')
# print(H.history['val_accuracy'])
# print('')
# Out:
# dict_keys(['val_accuracy', 'loss', 'val_loss', 'accuracy'])

# %%
# plot the training loss and accuracy
from matplotlib import pyplot as plt
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, num_of_epochs), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, num_of_epochs), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, num_of_epochs), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, num_of_epochs), H.history["val_accuracy"], label="val_accuracy")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig(plot_save_path)
plt.show()
