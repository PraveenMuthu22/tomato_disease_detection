# %% [markdown]
# # Arguments

# %%
# vgg16-ft-pv-self-eb,ap,lm,ct
num_of_epochs = 100
batch_size = 32
dataset_path_plantvillage = '../datasets/plantvillage'
dataset_path_self = '../datasets/self'
dataset_path_validation = '../datasets/validation'

dataset_paths = [dataset_path_plantvillage, dataset_path_self, dataset_path_validation]

warmup_model_path = 'model-warmup.h5'
model_save_path = 'model-final.h5'
checkpoint_path = 'checkpoints-finetuning.hdf5'

input_width = 224
input_height = 224
input_depth = 3

# %% [markdown]
# # Select training classes

# %%
class_paths_training = ['../datasets/self/___Early_blight', '../datasets/self/___Appids', '../datasets/self/___Leaf_miner', '../datasets/self/___Curly_top_virus']

# %% [markdown]
# # Load dataset

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.preprocessing.image   import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.layers import Input
from keras.models import Model
from keras .applications import VGG16
from keras.optimizers import SGD
from keras.models import Model
from imutils import paths
import numpy as np
import os

import sys
sys.path.append('..')

from utils.preprocessors.resize_image_preprocessor import resizeImagePreprocessor
from utils.preprocessors.img_to_array_preprocessor import ImgToArrayPreprocessor
from utils.io.dataset_loader import DatasetLoader

# construct the image generator for data augmentation
aug = ImageDataGenerator(   rotation_range=30,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            shear_range=0.2,
                            zoom_range=0.2,
                            horizontal_flip=True,
                            fill_mode='nearest')

def load_datasets(path_list):
    # Load image paths
    image_paths = []
    print("[INFO] loading images...")
    for path in path_list:
        image_paths.extend(list(paths.list_images(path)))
        
    # Get unique classnames

    class_names = [pt.split(os.path.sep)[-2] for pt in image_paths]
    class_names = [str(x) for x in np.unique(class_names)]

    # Initial image preprocessing
    aap = resizeImagePreprocessor(input_width, input_height)
    iap= ImgToArrayPreprocessor()

    #Load image data and perform image data preprocessing
    dl = DatasetLoader(preprocessors=[aap,iap])
    (data,labels)  = dl.load(image_paths,verbose=500)
    data = data.astype("float") / 255.0


    # train test split
    (train_x,test_x,train_y,test_y) = train_test_split(data,labels,test_size=0.25,random_state=42)

    # convert the labels from integers to vectors
    train_y = LabelBinarizer().fit_transform(train_y)
    test_y = LabelBinarizer().fit_transform(test_y)
    
    return (train_x,test_x,train_y,test_y, class_names)

(train_x,test_x,train_y,test_y, class_names) = load_datasets(class_paths_training)
# Out:
# Using TensorFlow backend.
# [INFO] loading images...
# [INFO]: Processed 500/4849
# [INFO]: Processed 1000/4849
# [INFO]: Processed 1500/4849
# [INFO]: Processed 2000/4849
# [INFO]: Processed 2500/4849
# [INFO]: Processed 3000/4849
# [INFO]: Processed 3500/4849
# [INFO]: Processed 4000/4849
# [INFO]: Processed 4500/4849

# %% [markdown]
# # Load model from disk

# %%
# import tensorflow as tf
# print(tf.__version__)


# model = tf.keras.models.load_model(
#     warmup_model_path,
#     custom_objects=None,
#     compile=False
# )

from keras.models import load_model

model = load_model(warmup_model_path)

# %% [markdown]
# # Print index of layers

# %%
# iterate for all layers in the network and print its' index value
for (i,layer) in enumerate(model.layers):
    print("[INFO] {}\t{}".format(i,layer.__class__.__name__))
# Out:
# [INFO] 0	InputLayer
# [INFO] 1	Conv2D
# [INFO] 2	Conv2D
# [INFO] 3	MaxPooling2D
# [INFO] 4	Conv2D
# [INFO] 5	Conv2D
# [INFO] 6	MaxPooling2D
# [INFO] 7	Conv2D
# [INFO] 8	Conv2D
# [INFO] 9	Conv2D
# [INFO] 10	MaxPooling2D
# [INFO] 11	Conv2D
# [INFO] 12	Conv2D
# [INFO] 13	Conv2D
# [INFO] 14	MaxPooling2D
# [INFO] 15	Conv2D
# [INFO] 16	Conv2D
# [INFO] 17	Conv2D
# [INFO] 18	MaxPooling2D
# [INFO] 19	Flatten
# [INFO] 20	Dense
# [INFO] 21	Dropout
# [INFO] 22	Dense

# %% [markdown]
# # Unfreeze final CONV layers

# %%
for layer in model.layers[15:]:
    layer.trainable = True
print('unfrozen')
# Out:
# unfrozen

# %% [markdown]
# # Compile model

# %%
from keras.optimizers import SGD

# Build the model from the new
print("[INFO] re-compiling model ...")
opt = SGD(lr=0.001, momentum=0.09)
# Fine-tuning with a small learning rate
model.compile(loss = 'categorical_crossentropy',optimizer = opt,
              metrics=['accuracy'])
# Out:
# [INFO] re-compiling model ...

# %% [markdown]
# # Checkpoints

# %%
from keras.callbacks import ModelCheckpoint


checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', mode='min', 
save_best_only=True, verbose=1)

callbacks = [checkpoint]

# %%
#load checkpoints if existing

import os

if(os.path.exists(checkpoint_path)):
    model.load_weights(checkpoint_path)

# %% [markdown]
# # Training Monitor

# %%
from utils.callbacks.training_monitor import TrainingMonitor
import pathlib
import json
import os

fig_path = "plot"
json_path = "values.json"
values_path = 'values.json'

start_epoch = 0

callbacks.append(TrainingMonitor(fig_path, json_path, start_epoch))

# %% [markdown]
# # Fit model

# %%
num_of_epochs = 100

H = model.fit_generator(
    aug.flow(train_x,train_y, batch_size = 32),
             validation_data = (test_x,test_y),
             epochs=num_of_epochs,
             steps_per_epoch = len(train_x) //32,
             verbose = 1,
             callbacks=callbacks)
# Out:
# Epoch 1/100
# 113/113 [==============================] - 66s 587ms/step - loss: 0.3388 - accuracy: 0.8812 - val_loss: 0.2096 - val_accuracy: 0.9225
#
# Epoch 00001: val_loss improved from inf to 0.20955, saving model to checkpoints-finetuning.hdf5
# Epoch 2/100
# 113/113 [==============================] - 57s 504ms/step - loss: 0.2260 - accuracy: 0.9176 - val_loss: 0.2860 - val_accuracy: 0.8862
#
# Epoch 00002: val_loss did not improve from 0.20955
# Epoch 3/100
# 113/113 [==============================] - 55s 490ms/step - loss: 0.2008 - accuracy: 0.9323 - val_loss: 0.1313 - val_accuracy: 0.9505
#
# Epoch 00003: val_loss improved from 0.20955 to 0.13130, saving model to checkpoints-finetuning.hdf5
# Epoch 4/100
# 113/113 [==============================] - 55s 487ms/step - loss: 0.1703 - accuracy: 0.9409 - val_loss: 0.1315 - val_accuracy: 0.9547
#
# Epoch 00004: val_loss did not improve from 0.13130
# Epoch 5/100
# 113/113 [==============================] - 55s 489ms/step - loss: 0.1465 - accuracy: 0.9501 - val_loss: 0.1144 - val_accuracy: 0.9604
#
# Epoch 00005: val_loss improved from 0.13130 to 0.11437, saving model to checkpoints-finetuning.hdf5
# Epoch 6/100
# 113/113 [==============================] - 55s 484ms/step - loss: 0.1398 - accuracy: 0.9523 - val_loss: 0.1225 - val_accuracy: 0.9555
#
# Epoch 00006: val_loss did not improve from 0.11437
# Epoch 7/100
# 113/113 [==============================] - 55s 486ms/step - loss: 0.1247 - accuracy: 0.9567 - val_loss: 0.1100 - val_accuracy: 0.9547
#
# Epoch 00007: val_loss improved from 0.11437 to 0.10996, saving model to checkpoints-finetuning.hdf5
# Epoch 8/100
# 113/113 [==============================] - 55s 489ms/step - loss: 0.1473 - accuracy: 0.9501 - val_loss: 0.1214 - val_accuracy: 0.9621
#
# Epoch 00008: val_loss did not improve from 0.10996
# Epoch 9/100
# 113/113 [==============================] - 54s 480ms/step - loss: 0.1073 - accuracy: 0.9639 - val_loss: 0.0890 - val_accuracy: 0.9703
#
# Epoch 00009: val_loss improved from 0.10996 to 0.08895, saving model to checkpoints-finetuning.hdf5
# Epoch 10/100
# 113/113 [==============================] - 55s 491ms/step - loss: 0.1103 - accuracy: 0.9612 - val_loss: 0.0879 - val_accuracy: 0.9687
#
# Epoch 00010: val_loss improved from 0.08895 to 0.08786, saving model to checkpoints-finetuning.hdf5
# Epoch 11/100
# 113/113 [==============================] - 54s 481ms/step - loss: 0.0997 - accuracy: 0.9642 - val_loss: 0.0854 - val_accuracy: 0.9711
#
# Epoch 00011: val_loss improved from 0.08786 to 0.08537, saving model to checkpoints-finetuning.hdf5
# Epoch 12/100
# 113/113 [==============================] - 54s 478ms/step - loss: 0.1003 - accuracy: 0.9637 - val_loss: 0.0835 - val_accuracy: 0.9711
#
# Epoch 00012: val_loss improved from 0.08537 to 0.08345, saving model to checkpoints-finetuning.hdf5
# Epoch 13/100
# 113/113 [==============================] - 54s 480ms/step - loss: 0.0877 - accuracy: 0.9684 - val_loss: 0.1160 - val_accuracy: 0.9604
#
# Epoch 00013: val_loss did not improve from 0.08345
# Epoch 14/100
# 113/113 [==============================] - 55s 484ms/step - loss: 0.0886 - accuracy: 0.9692 - val_loss: 0.0801 - val_accuracy: 0.9687
#
# Epoch 00014: val_loss improved from 0.08345 to 0.08006, saving model to checkpoints-finetuning.hdf5
# Epoch 15/100
# 113/113 [==============================] - 54s 477ms/step - loss: 0.0896 - accuracy: 0.9684 - val_loss: 0.0914 - val_accuracy: 0.9687
#
# Epoch 00015: val_loss did not improve from 0.08006
# Epoch 16/100
# 113/113 [==============================] - 54s 476ms/step - loss: 0.0872 - accuracy: 0.9709 - val_loss: 0.1020 - val_accuracy: 0.9678
#
# Epoch 00016: val_loss did not improve from 0.08006
# Epoch 17/100
# 113/113 [==============================] - 54s 474ms/step - loss: 0.0752 - accuracy: 0.9714 - val_loss: 0.1333 - val_accuracy: 0.9530
#
# Epoch 00017: val_loss did not improve from 0.08006
# Epoch 18/100
# 113/113 [==============================] - 53s 473ms/step - loss: 0.0791 - accuracy: 0.9734 - val_loss: 0.0802 - val_accuracy: 0.9761
#
# Epoch 00018: val_loss did not improve from 0.08006
# Epoch 19/100
# 113/113 [==============================] - 54s 474ms/step - loss: 0.0707 - accuracy: 0.9739 - val_loss: 0.0763 - val_accuracy: 0.9769
#
# Epoch 00019: val_loss improved from 0.08006 to 0.07634, saving model to checkpoints-finetuning.hdf5
# Epoch 20/100
# 113/113 [==============================] - 53s 473ms/step - loss: 0.0538 - accuracy: 0.9797 - val_loss: 0.0918 - val_accuracy: 0.9720
#
# Epoch 00020: val_loss did not improve from 0.07634
# Epoch 21/100
# 113/113 [==============================] - 54s 475ms/step - loss: 0.0711 - accuracy: 0.9770 - val_loss: 0.0712 - val_accuracy: 0.9761
#
# Epoch 00021: val_loss improved from 0.07634 to 0.07121, saving model to checkpoints-finetuning.hdf5
# Epoch 22/100
# 113/113 [==============================] - 53s 468ms/step - loss: 0.0654 - accuracy: 0.9777 - val_loss: 0.0806 - val_accuracy: 0.9753
#
# Epoch 00022: val_loss did not improve from 0.07121
# Epoch 23/100
# 113/113 [==============================] - 53s 470ms/step - loss: 0.0585 - accuracy: 0.9792 - val_loss: 0.0712 - val_accuracy: 0.9753
#
# Epoch 00023: val_loss did not improve from 0.07121
# Epoch 24/100
# 113/113 [==============================] - 53s 467ms/step - loss: 0.0591 - accuracy: 0.9781 - val_loss: 0.1288 - val_accuracy: 0.9588
#
# Epoch 00024: val_loss did not improve from 0.07121
# Epoch 25/100
# 113/113 [==============================] - 53s 468ms/step - loss: 0.0634 - accuracy: 0.9770 - val_loss: 0.0878 - val_accuracy: 0.9720
#
# Epoch 00025: val_loss did not improve from 0.07121
# Epoch 26/100
# 113/113 [==============================] - 53s 465ms/step - loss: 0.0567 - accuracy: 0.9814 - val_loss: 0.0816 - val_accuracy: 0.9744
#
# Epoch 00026: val_loss did not improve from 0.07121
# Epoch 27/100
# 113/113 [==============================] - 52s 458ms/step - loss: 0.0501 - accuracy: 0.9861 - val_loss: 0.0918 - val_accuracy: 0.9695
#
# Epoch 00027: val_loss did not improve from 0.07121
# Epoch 28/100
# 113/113 [==============================] - 52s 464ms/step - loss: 0.0516 - accuracy: 0.9831 - val_loss: 0.1048 - val_accuracy: 0.9703
#
# Epoch 00028: val_loss did not improve from 0.07121
# Epoch 29/100
# 113/113 [==============================] - 52s 461ms/step - loss: 0.0503 - accuracy: 0.9828 - val_loss: 0.1223 - val_accuracy: 0.9637
#
# Epoch 00029: val_loss did not improve from 0.07121
# Epoch 30/100
# 113/113 [==============================] - 52s 464ms/step - loss: 0.0492 - accuracy: 0.9828 - val_loss: 0.1054 - val_accuracy: 0.9662
#
# Epoch 00030: val_loss did not improve from 0.07121
# Epoch 31/100
# 113/113 [==============================] - 53s 468ms/step - loss: 0.0553 - accuracy: 0.9806 - val_loss: 0.0876 - val_accuracy: 0.9728
#
# Epoch 00031: val_loss did not improve from 0.07121
# Epoch 32/100
# 113/113 [==============================] - 52s 462ms/step - loss: 0.0530 - accuracy: 0.9811 - val_loss: 0.0841 - val_accuracy: 0.9744
#
# Epoch 00032: val_loss did not improve from 0.07121
# Epoch 33/100
# 113/113 [==============================] - 52s 458ms/step - loss: 0.0457 - accuracy: 0.9839 - val_loss: 0.1055 - val_accuracy: 0.9720
#
# Epoch 00033: val_loss did not improve from 0.07121
# Epoch 34/100
# 113/113 [==============================] - 52s 459ms/step - loss: 0.0419 - accuracy: 0.9870 - val_loss: 0.1014 - val_accuracy: 0.9728
#
# Epoch 00034: val_loss did not improve from 0.07121
# Epoch 35/100
# 113/113 [==============================] - 51s 455ms/step - loss: 0.0351 - accuracy: 0.9883 - val_loss: 0.0722 - val_accuracy: 0.9777
#
# Epoch 00035: val_loss did not improve from 0.07121
# Epoch 36/100
# 113/113 [==============================] - 52s 459ms/step - loss: 0.0489 - accuracy: 0.9834 - val_loss: 0.0801 - val_accuracy: 0.9736
#
# Epoch 00036: val_loss did not improve from 0.07121
# Epoch 37/100
# 113/113 [==============================] - 52s 462ms/step - loss: 0.0320 - accuracy: 0.9897 - val_loss: 0.1124 - val_accuracy: 0.9670
#
# Epoch 00037: val_loss did not improve from 0.07121
# Epoch 38/100
# 113/113 [==============================] - 52s 459ms/step - loss: 0.0401 - accuracy: 0.9858 - val_loss: 0.0885 - val_accuracy: 0.9695
#
# Epoch 00038: val_loss did not improve from 0.07121
# Epoch 39/100
# 113/113 [==============================] - 52s 465ms/step - loss: 0.0278 - accuracy: 0.9920 - val_loss: 0.1101 - val_accuracy: 0.9687
#
# Epoch 00039: val_loss did not improve from 0.07121
# Epoch 40/100
# 113/113 [==============================] - 52s 460ms/step - loss: 0.0439 - accuracy: 0.9861 - val_loss: 0.0873 - val_accuracy: 0.9736
#
# Epoch 00040: val_loss did not improve from 0.07121
# Epoch 41/100
# 113/113 [==============================] - 52s 458ms/step - loss: 0.0384 - accuracy: 0.9875 - val_loss: 0.0887 - val_accuracy: 0.9736
#
# Epoch 00041: val_loss did not improve from 0.07121
# Epoch 42/100
# 113/113 [==============================] - 51s 456ms/step - loss: 0.0359 - accuracy: 0.9872 - val_loss: 0.0867 - val_accuracy: 0.9769
#
# Epoch 00042: val_loss did not improve from 0.07121
# Epoch 43/100
# 113/113 [==============================] - 51s 454ms/step - loss: 0.0355 - accuracy: 0.9889 - val_loss: 0.1033 - val_accuracy: 0.9695
#
# Epoch 00043: val_loss did not improve from 0.07121
# Epoch 44/100
# 113/113 [==============================] - 52s 460ms/step - loss: 0.0295 - accuracy: 0.9920 - val_loss: 0.0943 - val_accuracy: 0.9753
#
# Epoch 00044: val_loss did not improve from 0.07121
# Epoch 45/100
# 113/113 [==============================] - 51s 455ms/step - loss: 0.0262 - accuracy: 0.9916 - val_loss: 0.1096 - val_accuracy: 0.9678
#
# Epoch 00045: val_loss did not improve from 0.07121
# Epoch 46/100
# 113/113 [==============================] - 53s 465ms/step - loss: 0.0331 - accuracy: 0.9892 - val_loss: 0.0849 - val_accuracy: 0.9777
#
# Epoch 00046: val_loss did not improve from 0.07121
# Epoch 47/100
# 113/113 [==============================] - 52s 457ms/step - loss: 0.0339 - accuracy: 0.9887 - val_loss: 0.1231 - val_accuracy: 0.9629
#
# Epoch 00047: val_loss did not improve from 0.07121
# Epoch 48/100
# 113/113 [==============================] - 51s 454ms/step - loss: 0.0334 - accuracy: 0.9889 - val_loss: 0.0893 - val_accuracy: 0.9753
#
# Epoch 00048: val_loss did not improve from 0.07121
# Epoch 49/100
# 113/113 [==============================] - 52s 458ms/step - loss: 0.0248 - accuracy: 0.9928 - val_loss: 0.0857 - val_accuracy: 0.9777
#
# Epoch 00049: val_loss did not improve from 0.07121
# Epoch 50/100
# 113/113 [==============================] - 51s 452ms/step - loss: 0.0284 - accuracy: 0.9911 - val_loss: 0.0746 - val_accuracy: 0.9786
#
# Epoch 00050: val_loss did not improve from 0.07121
# Epoch 51/100
# 113/113 [==============================] - 51s 451ms/step - loss: 0.0307 - accuracy: 0.9889 - val_loss: 0.0965 - val_accuracy: 0.9744
#
# Epoch 00051: val_loss did not improve from 0.07121
# Epoch 52/100
# 113/113 [==============================] - 51s 451ms/step - loss: 0.0224 - accuracy: 0.9928 - val_loss: 0.0825 - val_accuracy: 0.9794
#
# Epoch 00052: val_loss did not improve from 0.07121
# Epoch 53/100
# 113/113 [==============================] - 51s 456ms/step - loss: 0.0255 - accuracy: 0.9925 - val_loss: 0.1192 - val_accuracy: 0.9703
#
# Epoch 00053: val_loss did not improve from 0.07121
# Epoch 54/100
# 113/113 [==============================] - 51s 455ms/step - loss: 0.0352 - accuracy: 0.9870 - val_loss: 0.0967 - val_accuracy: 0.9687
#
# Epoch 00054: val_loss did not improve from 0.07121
# Epoch 55/100
# 113/113 [==============================] - 51s 453ms/step - loss: 0.0330 - accuracy: 0.9883 - val_loss: 0.0670 - val_accuracy: 0.9810
#
# Epoch 00055: val_loss improved from 0.07121 to 0.06705, saving model to checkpoints-finetuning.hdf5
# Epoch 56/100
# 113/113 [==============================] - 51s 448ms/step - loss: 0.0323 - accuracy: 0.9878 - val_loss: 0.0978 - val_accuracy: 0.9711
#
# Epoch 00056: val_loss did not improve from 0.06705
# Epoch 57/100
# 113/113 [==============================] - 52s 457ms/step - loss: 0.0233 - accuracy: 0.9925 - val_loss: 0.0750 - val_accuracy: 0.9769
#
# Epoch 00057: val_loss did not improve from 0.06705
# Epoch 58/100
# 113/113 [==============================] - 51s 453ms/step - loss: 0.0214 - accuracy: 0.9936 - val_loss: 0.0816 - val_accuracy: 0.9744
#
# Epoch 00058: val_loss did not improve from 0.06705
# Epoch 59/100
# 113/113 [==============================] - 51s 448ms/step - loss: 0.0286 - accuracy: 0.9911 - val_loss: 0.1036 - val_accuracy: 0.9703
#
# Epoch 00059: val_loss did not improve from 0.06705
# Epoch 60/100
# 113/113 [==============================] - 51s 451ms/step - loss: 0.0143 - accuracy: 0.9961 - val_loss: 0.0606 - val_accuracy: 0.9810
#
# Epoch 00060: val_loss improved from 0.06705 to 0.06063, saving model to checkpoints-finetuning.hdf5
# Epoch 61/100
# 113/113 [==============================] - 51s 454ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.0983 - val_accuracy: 0.9753
#
# Epoch 00061: val_loss did not improve from 0.06063
# Epoch 62/100
# 113/113 [==============================] - 51s 448ms/step - loss: 0.0285 - accuracy: 0.9900 - val_loss: 0.0818 - val_accuracy: 0.9728
#
# Epoch 00062: val_loss did not improve from 0.06063
# Epoch 63/100
# 113/113 [==============================] - 50s 446ms/step - loss: 0.0311 - accuracy: 0.9886 - val_loss: 0.0762 - val_accuracy: 0.9786
#
# Epoch 00063: val_loss did not improve from 0.06063
# Epoch 64/100
# 113/113 [==============================] - 50s 443ms/step - loss: 0.0250 - accuracy: 0.9922 - val_loss: 0.1014 - val_accuracy: 0.9736
#
# Epoch 00064: val_loss did not improve from 0.06063
# Epoch 65/100
# 113/113 [==============================] - 50s 446ms/step - loss: 0.0220 - accuracy: 0.9936 - val_loss: 0.0784 - val_accuracy: 0.9802
#
# Epoch 00065: val_loss did not improve from 0.06063
# Epoch 66/100
# 113/113 [==============================] - 51s 447ms/step - loss: 0.0218 - accuracy: 0.9928 - val_loss: 0.0692 - val_accuracy: 0.9810
#
# Epoch 00066: val_loss did not improve from 0.06063
# Epoch 67/100
# 113/113 [==============================] - 51s 451ms/step - loss: 0.0213 - accuracy: 0.9934 - val_loss: 0.0679 - val_accuracy: 0.9794
#
# Epoch 00067: val_loss did not improve from 0.06063
# Epoch 68/100
# 113/113 [==============================] - 51s 452ms/step - loss: 0.0231 - accuracy: 0.9931 - val_loss: 0.1269 - val_accuracy: 0.9646
#
# Epoch 00068: val_loss did not improve from 0.06063
# Epoch 69/100
# 113/113 [==============================] - 50s 445ms/step - loss: 0.0174 - accuracy: 0.9953 - val_loss: 0.0987 - val_accuracy: 0.9720
#
# Epoch 00069: val_loss did not improve from 0.06063
# Epoch 70/100
# 113/113 [==============================] - 50s 443ms/step - loss: 0.0232 - accuracy: 0.9934 - val_loss: 0.1129 - val_accuracy: 0.9703
#
# Epoch 00070: val_loss did not improve from 0.06063
# Epoch 71/100
# 113/113 [==============================] - 50s 445ms/step - loss: 0.0167 - accuracy: 0.9958 - val_loss: 0.1017 - val_accuracy: 0.9744
#
# Epoch 00071: val_loss did not improve from 0.06063
# Epoch 72/100
# 113/113 [==============================] - 50s 447ms/step - loss: 0.0207 - accuracy: 0.9934 - val_loss: 0.0823 - val_accuracy: 0.9761
#
# Epoch 00072: val_loss did not improve from 0.06063
# Epoch 73/100
# 113/113 [==============================] - 50s 444ms/step - loss: 0.0179 - accuracy: 0.9936 - val_loss: 0.0744 - val_accuracy: 0.9777
#
# Epoch 00073: val_loss did not improve from 0.06063
# Epoch 74/100
# 113/113 [==============================] - 50s 443ms/step - loss: 0.0209 - accuracy: 0.9947 - val_loss: 0.1825 - val_accuracy: 0.9514
#
# Epoch 00074: val_loss did not improve from 0.06063
# Epoch 75/100
# 113/113 [==============================] - 50s 439ms/step - loss: 0.0223 - accuracy: 0.9914 - val_loss: 0.1310 - val_accuracy: 0.9654
#
# Epoch 00075: val_loss did not improve from 0.06063
# Epoch 76/100
# 113/113 [==============================] - 50s 441ms/step - loss: 0.0199 - accuracy: 0.9950 - val_loss: 0.0975 - val_accuracy: 0.9769
#
# Epoch 00076: val_loss did not improve from 0.06063
# Epoch 77/100
# 113/113 [==============================] - 50s 439ms/step - loss: 0.0197 - accuracy: 0.9933 - val_loss: 0.0807 - val_accuracy: 0.9802
#
# Epoch 00077: val_loss did not improve from 0.06063
# Epoch 78/100
# 113/113 [==============================] - 50s 442ms/step - loss: 0.0162 - accuracy: 0.9933 - val_loss: 0.0857 - val_accuracy: 0.9769
#
# Epoch 00078: val_loss did not improve from 0.06063
# Epoch 79/100
# 113/113 [==============================] - 49s 437ms/step - loss: 0.0225 - accuracy: 0.9931 - val_loss: 0.0754 - val_accuracy: 0.9810
#
# Epoch 00079: val_loss did not improve from 0.06063
# Epoch 80/100
# 113/113 [==============================] - 51s 448ms/step - loss: 0.0137 - accuracy: 0.9964 - val_loss: 0.0880 - val_accuracy: 0.9786
#
# Epoch 00080: val_loss did not improve from 0.06063
# Epoch 81/100
# 113/113 [==============================] - 50s 442ms/step - loss: 0.0196 - accuracy: 0.9925 - val_loss: 0.1152 - val_accuracy: 0.9687
#
# Epoch 00081: val_loss did not improve from 0.06063
# Epoch 82/100
# 113/113 [==============================] - 50s 445ms/step - loss: 0.0179 - accuracy: 0.9942 - val_loss: 0.0759 - val_accuracy: 0.9794
#
# Epoch 00082: val_loss did not improve from 0.06063
# Epoch 83/100
# 113/113 [==============================] - 50s 443ms/step - loss: 0.0195 - accuracy: 0.9931 - val_loss: 0.0594 - val_accuracy: 0.9827
#
# Epoch 00083: val_loss improved from 0.06063 to 0.05943, saving model to checkpoints-finetuning.hdf5
# Epoch 84/100
# 113/113 [==============================] - 51s 451ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.0743 - val_accuracy: 0.9802
#
# Epoch 00084: val_loss did not improve from 0.05943
# Epoch 85/100
# 113/113 [==============================] - 50s 443ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.0800 - val_accuracy: 0.9786
#
# Epoch 00085: val_loss did not improve from 0.05943
# Epoch 86/100
# 113/113 [==============================] - 50s 444ms/step - loss: 0.0230 - accuracy: 0.9939 - val_loss: 0.0995 - val_accuracy: 0.9744
#
# Epoch 00086: val_loss did not improve from 0.05943
# Epoch 87/100
# 113/113 [==============================] - 51s 448ms/step - loss: 0.0170 - accuracy: 0.9947 - val_loss: 0.0929 - val_accuracy: 0.9761
#
# Epoch 00087: val_loss did not improve from 0.05943
# Epoch 88/100
# 113/113 [==============================] - 50s 441ms/step - loss: 0.0179 - accuracy: 0.9950 - val_loss: 0.0736 - val_accuracy: 0.9819
#
# Epoch 00088: val_loss did not improve from 0.05943
# Epoch 89/100
# 113/113 [==============================] - 50s 444ms/step - loss: 0.0155 - accuracy: 0.9953 - val_loss: 0.0703 - val_accuracy: 0.9827
#
# Epoch 00089: val_loss did not improve from 0.05943
# Epoch 90/100
# 113/113 [==============================] - 51s 447ms/step - loss: 0.0184 - accuracy: 0.9945 - val_loss: 0.0823 - val_accuracy: 0.9810
#
# Epoch 00090: val_loss did not improve from 0.05943
# Epoch 91/100
# 113/113 [==============================] - 50s 443ms/step - loss: 0.0179 - accuracy: 0.9942 - val_loss: 0.0964 - val_accuracy: 0.9769
#
# Epoch 00091: val_loss did not improve from 0.05943
# Epoch 92/100
# 113/113 [==============================] - 50s 442ms/step - loss: 0.0220 - accuracy: 0.9917 - val_loss: 0.1144 - val_accuracy: 0.9654
#
# Epoch 00092: val_loss did not improve from 0.05943
# Epoch 93/100
# 113/113 [==============================] - 49s 435ms/step - loss: 0.0178 - accuracy: 0.9953 - val_loss: 0.1180 - val_accuracy: 0.9678
#
# Epoch 00093: val_loss did not improve from 0.05943
# Epoch 94/100
# 113/113 [==============================] - 49s 434ms/step - loss: 0.0171 - accuracy: 0.9945 - val_loss: 0.0869 - val_accuracy: 0.9786
#
# Epoch 00094: val_loss did not improve from 0.05943
# Epoch 95/100
# 113/113 [==============================] - 50s 444ms/step - loss: 0.0173 - accuracy: 0.9947 - val_loss: 0.2117 - val_accuracy: 0.9489
#
# Epoch 00095: val_loss did not improve from 0.05943
# Epoch 96/100
# 113/113 [==============================] - 50s 443ms/step - loss: 0.0156 - accuracy: 0.9947 - val_loss: 0.1212 - val_accuracy: 0.9670
#
# Epoch 00096: val_loss did not improve from 0.05943
# Epoch 97/100
# 113/113 [==============================] - 50s 442ms/step - loss: 0.0155 - accuracy: 0.9958 - val_loss: 0.0887 - val_accuracy: 0.9794
#
# Epoch 00097: val_loss did not improve from 0.05943
# Epoch 98/100
# 113/113 [==============================] - 50s 446ms/step - loss: 0.0166 - accuracy: 0.9956 - val_loss: 0.1237 - val_accuracy: 0.9670
#
# Epoch 00098: val_loss did not improve from 0.05943
# Epoch 99/100
# 113/113 [==============================] - 50s 442ms/step - loss: 0.0139 - accuracy: 0.9945 - val_loss: 0.1284 - val_accuracy: 0.9670
#
# Epoch 00099: val_loss did not improve from 0.05943
# Epoch 100/100
# 113/113 [==============================] - 49s 438ms/step - loss: 0.0125 - accuracy: 0.9972 - val_loss: 0.1037 - val_accuracy: 0.9744
#
# Epoch 00100: val_loss did not improve from 0.05943

# %% [markdown]
# # Save model

# %%
model.save(model_save_path)

# %% [markdown]
# # Evaluate with 20%

# %%
from sklearn.metrics import classification_report

print("[INFO] evaluating after initialization...")
predictions = model.predict(test_x,batch_size=batch_size)

print(classification_report(test_y.argmax(axis =1),
                            predictions.argmax(axis =1),
                            target_names=class_names, 
                            digits=4))
# Out:
# [INFO] evaluating after initialization...
#                     precision    recall  f1-score   support
#
#          ___Appids     0.9876    0.9876    0.9876       242
# ___Curly_top_virus     0.9921    0.8803    0.9328       142
#    ___Early_blight     0.9869    0.9818    0.9843       384
#      ___Leaf_miner     0.9525    0.9910    0.9714       445
#
#        avg / total     0.9750    0.9744    0.9742      1213

# %% [markdown]
# # Evaluate with validation images

# %%
class_paths_validation = ['../datasets/validation/___Early_blight', '../datasets/validation/___Appids', '../datasets/validation/___Leaf_miner', '../datasets/self/___Curly_top_virus']

# %%
(train_x,test_x,train_y,test_y, class_names) = load_datasets(class_paths_validation)

from sklearn.metrics import classification_report

print("[INFO] evaluating with validation set...")
predictions = model.predict(test_x,batch_size=batch_size)

print(classification_report(test_y.argmax(axis =1),
                            predictions.argmax(axis =1),
                            target_names=class_names, 
                            digits=4))
# Out:
# [INFO] loading images...
# [INFO]: Processed 500/619
# [INFO] evaluating with validation set...
#                     precision    recall  f1-score   support
#
#          ___Appids     0.8571    0.6667    0.7500         9
# ___Curly_top_virus     0.9912    0.9576    0.9741       118
#    ___Early_blight     0.9167    0.9167    0.9167        12
#      ___Leaf_miner     0.6818    0.9375    0.7895        16
#
#        avg / total     0.9457    0.9355    0.9376       155
